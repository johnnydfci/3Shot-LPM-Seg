# %%
import os
import numpy as np
from PIL import Image
import pandas as pd
import cv2

# 定义目录
data_dir = './videos/MRI515_T2'
label_dir = os.path.join(data_dir, 'label_in_png_L4L5_renamed')

prompt_dir = 'manual_prompt_frame0_1_2'
prompt_dir = 'manual_prompt_frame0_1'
prompt_dir = 'manual_prompt_frame0'

# 自动分割结果所在目录（使用 nolap 版本）
auto_seg_dir = os.path.join(data_dir, prompt_dir, 'SAM2_seg_mask_nolap')

# 输出 CSV 文件路径（最终长格式结果）
csv_write_path = os.path.join(data_dir, prompt_dir, prompt_dir + '_area_results_long.csv')

# 检查所需目录是否存在
if not os.path.exists(label_dir) or not os.path.exists(auto_seg_dir):
    raise FileNotFoundError("One or more required directories do not exist!")

# 每个像素对应的实际面积（例如，单位为平方毫米）
spacing_factor = 0.6875 * 0.6875  # = 0.47265625

# 定义 4 个类别对应的目标像素值
classes = [50, 100, 150, 200]

results = []

# 处理每个 label 文件
for label_file in os.listdir(label_dir):
    # 假设文件名格式为 "123.png"，提取数字部分作为索引
    try:
        label_index = int(os.path.splitext(label_file)[0])
    except ValueError:
        print(f"Skipping file with non-numeric name: {label_file}")
        continue

    # 构造 label 文件的完整路径
    label_path = os.path.join(label_dir, label_file)
    label_index = str(int(label_index))
    
    # 构造自动分割 mask 的完整路径（4 个类别）
    auto_seg_paths = [
        os.path.join(auto_seg_dir, f"frame_{label_index}_obj_{i}.png")
        for i in range(1, len(classes) + 1)
    ]
    # 检查是否所有自动分割文件均存在
    if not all(os.path.exists(p) for p in auto_seg_paths):
        print(f"Auto segmentation files missing for {label_file}, skipping.")
        continue

    # 读取 label mask
    label_mask = np.array(Image.open(label_path))

    # 读取所有自动分割 mask
    auto_masks = [np.array(Image.open(p)) for p in auto_seg_paths]

    file_result = {"file_name": label_file}

    # 对每个类别进行面积计算
    for idx, class_val in enumerate(classes, start=1):
        # label: threshold处理，选取与目标值相近的像素（例如 ±10）
        label_class_mask = (np.abs(label_mask - class_val) < 10).astype(np.uint8)
        # auto segmentation：对应 obj_i 文件，使用相同的阈值条件
        auto_class_mask = (np.abs(auto_masks[idx - 1] - class_val) < 10).astype(np.uint8)
        # 调整自动分割 mask 的尺寸以匹配 label mask
        target_size = (label_mask.shape[1], label_mask.shape[0])
        auto_class_mask = cv2.resize(auto_class_mask, target_size, interpolation=cv2.INTER_NEAREST)

        # 计算面积：非0像素数 × spacing_factor
        label_area = np.sum(label_class_mask) * spacing_factor
        auto_area  = np.sum(auto_class_mask)  * spacing_factor

        # 保存结果，键名例如 "class1_label_area", "class1_auto_area"
        file_result[f"class{idx}_label_area"] = label_area
        file_result[f"class{idx}_auto_area"] = auto_area

    results.append(file_result)
    # 打印处理结果
    print(f"Processed {label_file}:", end=" ")
    for idx in range(1, len(classes) + 1):
        print(f"Class{idx} -> Label: {file_result[f'class{idx}_label_area']:.2f}, Auto: {file_result[f'class{idx}_auto_area']:.2f}; ", end="")
    print()

# 将宽格式结果转换为长格式
rows = []
for res in results:
    pid = os.path.splitext(res["file_name"])[0]  # 使用文件名（去除扩展名）作为 PID
    for cls in range(1, len(classes) + 1):
        rows.append({
            "PID": pid,
            "Class": cls,
            "Auto Area": res[f"class{cls}_auto_area"],
            "Manual Area": res[f"class{cls}_label_area"]
        })

results_long_df = pd.DataFrame(rows)

# 保存长格式结果到 CSV
results_long_df.to_csv(csv_write_path, index=False)
print(f"Results saved to {csv_write_path}")

# 输出预览
print(results_long_df.head())
# Out:
# Processed 00261.png: Class1 -> Label: 1229.85, Auto: 1153.28; Class2 -> Label: 1147.14, Auto: 1147.14; Class3 -> Label: 1229.38, Auto: 1198.66; Class4 -> Label: 1206.22, Auto: 1246.39;
# Processed 00212.png: Class1 -> Label: 1400.95, Auto: 1433.57; Class2 -> Label: 911.28, Auto: 960.91; Class3 -> Label: 851.25, Auto: 881.50; Class4 -> Label: 1524.32, Auto: 1505.41;
# Processed 00378.png: Class1 -> Label: 939.64, Auto: 860.71; Class2 -> Label: 842.75, Auto: 823.37; Class3 -> Label: 921.68, Auto: 912.23; Class4 -> Label: 829.51, Auto: 735.45;
# Processed 00071.png: Class1 -> Label: 1173.61, Auto: 1160.84; Class2 -> Label: 966.58, Auto: 1022.36; Class3 -> Label: 951.46, Auto: 947.20; Class4 -> Label: 1239.30, Auto: 1286.10;
# Processed 00328.png: Class1 -> Label: 893.32, Auto: 732.62; Class2 -> Label: 554.90, Auto: 570.97; Class3 -> Label: 586.09, Auto: 557.26; Class4 -> Label: 883.39, Auto: 950.04;
# Processed 00193.png: Class1 -> Label: 1064.42, Auto: 1003.45; Class2 -> Label: 1056.39, Auto: 1012.90; Class3 -> Label: 1023.30, Auto: 1002.98; Class4 -> Label: 1182.11, Auto: 1137.68;
# Processed 00401.png: Class1 -> Label: 857.40, Auto: 1006.76; Class2 -> Label: 744.91, Auto: 682.52; Class3 -> Label: 590.82, Auto: 703.31; Class4 -> Label: 1058.28, Auto: 1043.15;
# Processed 00049.png: Class1 -> Label: 1343.29, Auto: 1345.18; Class2 -> Label: 1115.00, Auto: 1144.30; Class3 -> Label: 1262.94, Auto: 1339.51; Class4 -> Label: 1274.28, Auto: 1457.67;
# Processed 00074.png: Class1 -> Label: 1219.45, Auto: 1107.43; Class2 -> Label: 767.59, Auto: 803.52; Class3 -> Label: 665.97, Auto: 1092.31; Class4 -> Label: 1385.83, Auto: 829.51;
# Processed 00136.png: Class1 -> Label: 1336.20, Auto: 1079.55; Class2 -> Label: 785.08, Auto: 825.73; Class3 -> Label: 864.96, Auto: 827.62; Class4 -> Label: 1428.84, Auto: 1558.35;
# Processed 00326.png: Class1 -> Label: 1921.35, Auto: 1896.77; Class2 -> Label: 1340.45, Auto: 1353.69; Class3 -> Label: 1180.22, Auto: 1493.59; Class4 -> Label: 2337.76, Auto: 1929.86;
# Processed 00209.png: Class1 -> Label: 1321.07, Auto: 1178.80; Class2 -> Label: 1069.15, Auto: 1094.20; Class3 -> Label: 1093.25, Auto: 1083.33; Class4 -> Label: 1378.74, Auto: 1374.48;
# Processed 00258.png: Class1 -> Label: 1095.62, Auto: 1106.02; Class2 -> Label: 1047.88, Auto: 1029.92; Class3 -> Label: 971.78, Auto: 759.56; Class4 -> Label: 1073.40, Auto: 1121.61;
# Processed 00217.png: Class1 -> Label: 1195.82, Auto: 906.08; Class2 -> Label: 1132.96, Auto: 1019.99; Class3 -> Label: 1133.43, Auto: 1033.70; Class4 -> Label: 1175.50, Auto: 678.73;
# Processed 00353.png: Class1 -> Label: 1346.12, Auto: 1388.66; Class2 -> Label: 1063.00, Auto: 1018.57; Class3 -> Label: 1028.97, Auto: 1063.00; Class4 -> Label: 1541.80, Auto: 1647.21;
# Processed 00094.png: Class1 -> Label: 1591.43, Auto: 1418.91; Class2 -> Label: 1037.48, Auto: 1063.95; Class3 -> Label: 944.37, Auto: 1018.10; Class4 -> Label: 1639.64, Auto: 1557.40;
# Processed 00078.png: Class1 -> Label: 1521.48, Auto: 1322.02; Class2 -> Label: 991.16, Auto: 1151.39; Class3 -> Label: 880.56, Auto: 861.65; Class4 -> Label: 1803.18, Auto: 1806.49;
# Processed 00263.png: Class1 -> Label: 1030.39, Auto: 1056.39; Class2 -> Label: 1152.34, Auto: 1137.21; Class3 -> Label: 1080.49, Auto: 1005.81; Class4 -> Label: 1243.56, Auto: 1338.09;
# Processed 00171.png: Class1 -> Label: 786.97, Auto: 1220.87; Class2 -> Label: 996.36, Auto: 1028.50; Class3 -> Label: 1085.22, Auto: 1130.12; Class4 -> Label: 803.99, Auto: 774.68;
# Processed 00099.png: Class1 -> Label: 1177.39, Auto: 1069.62; Class2 -> Label: 1116.41, Auto: 1124.92; Class3 -> Label: 1113.58, Auto: 1077.18; Class4 -> Label: 1178.80, Auto: 1269.55;
# Processed 00387.png: Class1 -> Label: 1416.08, Auto: 1439.24; Class2 -> Label: 1136.27, Auto: 1107.43; Class3 -> Label: 1054.50, Auto: 1036.54; Class4 -> Label: 1441.60, Auto: 1479.41;
# Processed 00388.png: Class1 -> Label: 979.82, Auto: 805.41; Class2 -> Label: 932.08, Auto: 895.68; Class3 -> Label: 865.91, Auto: 927.82; Class4 -> Label: 830.46, Auto: 1002.50;
# Processed 00037.png: Class1 -> Label: 1261.99, Auto: 855.51; Class2 -> Label: 1152.34, Auto: 1009.59; Class3 -> Label: 1103.65, Auto: 983.60; Class4 -> Label: 1201.49, Auto: 929.24;
# Processed 00355.png: Class1 -> Label: 1523.84, Auto: 1463.34; Class2 -> Label: 927.35, Auto: 940.11; Class3 -> Label: 1020.94, Auto: 1056.86; Class4 -> Label: 1518.17, Auto: 1431.68;
# Processed 00100.png: Class1 -> Label: 1374.96, Auto: 1437.35; Class2 -> Label: 783.66, Auto: 765.70; Class3 -> Label: 926.41, Auto: 1123.50; Class4 -> Label: 1276.17, Auto: 1378.27;
# Processed 00038.png: Class1 -> Label: 1318.71, Auto: 699.53; Class2 -> Label: 844.64, Auto: 1027.08; Class3 -> Label: 837.07, Auto: 694.33; Class4 -> Label: 1333.36, Auto: 1155.17;
# Processed 00028.png: Class1 -> Label: 1019.52, Auto: 963.27; Class2 -> Label: 1412.30, Auto: 1369.76; Class3 -> Label: 1342.34, Auto: 1379.21; Class4 -> Label: 1371.65, Auto: 1354.16;
# Processed 00233.png: Class1 -> Label: 1485.56, Auto: 911.28; Class2 -> Label: 571.91, Auto: 1005.81; Class3 -> Label: 722.22, Auto: 579.95; Class4 -> Label: 1493.59, Auto: 659.36;
# Processed 00286.png: Class1 -> Label: 1934.58, Auto: 1676.51; Class2 -> Label: 1143.36, Auto: 1135.32; Class3 -> Label: 1078.13, Auto: 990.21; Class4 -> Label: 1763.48, Auto: 1844.30;
# Processed 00184.png: Class1 -> Label: 1322.96, Auto: 690.55; Class2 -> Label: 1233.63, Auto: 1282.32; Class3 -> Label: 1106.96, Auto: 1093.73; Class4 -> Label: 1407.10, Auto: 1244.03;
# Processed 00152.png: Class1 -> Label: 1162.26, Auto: 985.49; Class2 -> Label: 908.92, Auto: 920.73; Class3 -> Label: 902.30, Auto: 828.09; Class4 -> Label: 1288.93, Auto: 1159.90;
# Processed 00066.png: Class1 -> Label: 1330.05, Auto: 1156.12; Class2 -> Label: 843.22, Auto: 906.08; Class3 -> Label: 829.51, Auto: 799.26; Class4 -> Label: 1422.70, Auto: 1351.32;
# Processed 00373.png: Class1 -> Label: 1107.91, Auto: 1132.48; Class2 -> Label: 935.39, Auto: 956.18; Class3 -> Label: 844.16, Auto: 856.45; Class4 -> Label: 1148.55, Auto: 1122.56;
# Processed 00068.png: Class1 -> Label: 1097.98, Auto: 934.91; Class2 -> Label: 542.14, Auto: 629.58; Class3 -> Label: 516.61, Auto: 475.96; Class4 -> Label: 1129.18, Auto: 1131.54;
# Processed 00097.png: Class1 -> Label: 1310.20, Auto: 1400.48; Class2 -> Label: 1257.27, Auto: 1209.53; Class3 -> Label: 1178.80, Auto: 1177.39; Class4 -> Label: 1507.77, Auto: 1616.01;
# Processed 00077.png: Class1 -> Label: 1643.43, Auto: 1362.20; Class2 -> Label: 857.40, Auto: 1028.03; Class3 -> Label: 836.60, Auto: 899.46; Class4 -> Label: 1757.34, Auto: 1706.76;
# Processed 00014.png: Class1 -> Label: 1594.27, Auto: 1652.41; Class2 -> Label: 720.33, Auto: 743.02; Class3 -> Label: 660.77, Auto: 731.20; Class4 -> Label: 1691.64, Auto: 1731.34;
# Processed 00109.png: Class1 -> Label: 1023.77, Auto: 1019.99; Class2 -> Label: 756.72, Auto: 766.18; Class3 -> Label: 838.96, Auto: 814.86; Class4 -> Label: 1057.80, Auto: 1073.40;
# Processed 00060.png: Class1 -> Label: 1829.18, Auto: 1724.72; Class2 -> Label: 993.52, Auto: 995.89; Class3 -> Label: 955.24, Auto: 929.71; Class4 -> Label: 1806.02, Auto: 1484.61;
# Processed 00053.png: Class1 -> Label: 1395.28, Auto: 1350.85; Class2 -> Label: 816.75, Auto: 951.93; Class3 -> Label: 808.24, Auto: 841.33; Class4 -> Label: 1524.32, Auto: 1455.78;
# Processed 00107.png: Class1 -> Label: 901.36, Auto: 962.33; Class2 -> Label: 1124.45, Auto: 1215.67; Class3 -> Label: 1168.41, Auto: 1252.07; Class4 -> Label: 1160.84, Auto: 1197.71;
# Processed 00210.png: Class1 -> Label: 1429.79, Auto: 1296.02; Class2 -> Label: 952.88, Auto: 969.89; Class3 -> Label: 998.72, Auto: 1008.18; Class4 -> Label: 1502.57, Auto: 1477.05;
# Processed 00131.png: Class1 -> Label: 1003.45, Auto: 846.53; Class2 -> Label: 1058.75, Auto: 932.55; Class3 -> Label: 964.69, Auto: 812.50; Class4 -> Label: 1170.30, Auto: 1039.37;
# Processed 00299.png: Class1 -> Label: 1730.87, Auto: 1573.95; Class2 -> Label: 846.53, Auto: 892.38; Class3 -> Label: 708.98, Auto: 722.22; Class4 -> Label: 1858.48, Auto: 1745.05;
# Processed 00098.png: Class1 -> Label: 1545.59, Auto: 1443.02; Class2 -> Label: 1308.79, Auto: 1327.69; Class3 -> Label: 1150.92, Auto: 1144.30; Class4 -> Label: 1715.74, Auto: 1811.22;
# Processed 00408.png: Class1 -> Label: 1124.45, Auto: 826.68; Class2 -> Label: 961.38, Auto: 974.62; Class3 -> Label: 976.04, Auto: 958.55; Class4 -> Label: 1545.59, Auto: 1514.39;
# Processed 00183.png: Class1 -> Label: 1549.84, Auto: 641.39; Class2 -> Label: 907.50, Auto: 889.54; Class3 -> Label: 833.77, Auto: 898.05; Class4 -> Label: 1505.88, Auto: 1438.29;
# Processed 00253.png: Class1 -> Label: 1267.66, Auto: 1226.07; Class2 -> Label: 882.45, Auto: 887.18; Class3 -> Label: 972.25, Auto: 898.52; Class4 -> Label: 1138.63, Auto: 1245.45;
# Processed 00365.png: Class1 -> Label: 1972.87, Auto: 1912.37; Class2 -> Label: 1282.32, Auto: 1222.29; Class3 -> Label: 1376.38, Auto: 1383.46; Class4 -> Label: 1918.51, Auto: 1827.29;
# Processed 00143.png: Class1 -> Label: 1292.24, Auto: 1313.98; Class2 -> Label: 1301.22, Auto: 1326.27; Class3 -> Label: 1324.38, Auto: 1370.23; Class4 -> Label: 1592.85, Auto: 1581.51;
# Processed 00302.png: Class1 -> Label: 916.01, Auto: 1006.29; Class2 -> Label: 852.20, Auto: 784.14; Class3 -> Label: 877.72, Auto: 829.04; Class4 -> Label: 954.77, Auto: 1056.39;
# Processed 00393.png: Class1 -> Label: 1303.59, Auto: 1114.05; Class2 -> Label: 788.86, Auto: 856.93; Class3 -> Label: 907.97, Auto: 694.80; Class4 -> Label: 1441.13, Auto: 1453.89;
# Processed 00267.png: Class1 -> Label: 1675.57, Auto: 1581.98; Class2 -> Label: 940.59, Auto: 1021.88; Class3 -> Label: 993.52, Auto: 1118.30; Class4 -> Label: 1773.41, Auto: 1607.03;
# Processed 00207.png: Class1 -> Label: 1236.00, Auto: 942.48; Class2 -> Label: 948.62, Auto: 944.84; Class3 -> Label: 849.36, Auto: 815.33; Class4 -> Label: 1457.67, Auto: 1472.80;
# Processed 00000.png: Class1 -> Label: 1326.75, Auto: 1326.75; Class2 -> Label: 953.35, Auto: 952.88; Class3 -> Label: 976.51, Auto: 976.51; Class4 -> Label: 1385.36, Auto: 1385.36;
# Processed 00048.png: Class1 -> Label: 945.79, Auto: 581.84; Class2 -> Label: 847.00, Auto: 1175.50; Class3 -> Label: 779.41, Auto: 757.67; Class4 -> Label: 1095.62, Auto: 1124.45;
# Processed 00224.png: Class1 -> Label: 1815.47, Auto: 1362.67; Class2 -> Label: 976.98, Auto: 933.50; Class3 -> Label: 1092.31, Auto: 1062.53; Class4 -> Label: 1126.34, Auto: 1149.50;
# Processed 00174.png: Class1 -> Label: 1004.87, Auto: 908.92; Class2 -> Label: 1388.19, Auto: 1494.54; Class3 -> Label: 1240.72, Auto: 1233.16; Class4 -> Label: 1251.12, Auto: 1272.39;
# Processed 00188.png: Class1 -> Label: 1487.45, Auto: 1253.96; Class2 -> Label: 1021.88, Auto: 991.16; Class3 -> Label: 1045.99, Auto: 1039.84; Class4 -> Label: 1508.25, Auto: 1535.66;
# Processed 00012.png: Class1 -> Label: 1188.73, Auto: 1104.60; Class2 -> Label: 1228.43, Auto: 1175.97; Class3 -> Label: 1174.08, Auto: 1034.64; Class4 -> Label: 1121.61, Auto: 1142.88;
# Processed 00319.png: Class1 -> Label: 1336.67, Auto: 1282.79; Class2 -> Label: 872.52, Auto: 868.74; Class3 -> Label: 1010.07, Auto: 1038.90; Class4 -> Label: 1224.65, Auto: 1285.62;
# Processed 00187.png: Class1 -> Label: 1219.93, Auto: 1170.77; Class2 -> Label: 655.10, Auto: 675.43; Class3 -> Label: 653.68, Auto: 763.81; Class4 -> Label: 1232.69, Auto: 1066.31;
# Processed 00017.png: Class1 -> Label: 1289.41, Auto: 862.60; Class2 -> Label: 882.92, Auto: 797.84; Class3 -> Label: 909.39, Auto: 782.25; Class4 -> Label: 1178.80, Auto: 1323.91;
# Processed 00381.png: Class1 -> Label: 1572.53, Auto: 1431.68; Class2 -> Label: 1086.64, Auto: 1087.58; Class3 -> Label: 1231.74, Auto: 1220.87; Class4 -> Label: 1235.52, Auto: 1332.42;
# Processed 00240.png: Class1 -> Label: 1076.71, Auto: 1031.34; Class2 -> Label: 1088.05, Auto: 1047.88; Class3 -> Label: 1220.40, Auto: 1226.54; Class4 -> Label: 1234.58, Auto: 1287.52;
# Processed 00366.png: Class1 -> Label: 1143.36, Auto: 1216.62; Class2 -> Label: 1236.47, Auto: 1067.26; Class3 -> Label: 1090.89, Auto: 966.11; Class4 -> Label: 1610.81, Auto: 1609.39;
# Processed 00270.png: Class1 -> Label: 1175.97, Auto: 951.93; Class2 -> Label: 913.64, Auto: 475.49; Class3 -> Label: 946.26, Auto: 480.69; Class4 -> Label: 950.98, Auto: 1103.65;
# Processed 00257.png: Class1 -> Label: 1459.56, Auto: 1229.38; Class2 -> Label: 833.29, Auto: 867.32; Class3 -> Label: 771.38, Auto: 899.94; Class4 -> Label: 1579.14, Auto: 1339.51;
# Processed 00291.png: Class1 -> Label: 1088.05, Auto: 1013.85; Class2 -> Label: 851.25, Auto: 855.04; Class3 -> Label: 775.16, Auto: 723.16; Class4 -> Label: 1031.34, Auto: 1043.62;
# Processed 00023.png: Class1 -> Label: 1449.16, Auto: 1044.57; Class2 -> Label: 1116.41, Auto: 1038.43; Class3 -> Label: 1103.65, Auto: 1178.80; Class4 -> Label: 1405.21, Auto: 1348.49;
# Processed 00129.png: Class1 -> Label: 1471.38, Auto: 1284.21; Class2 -> Label: 1240.72, Auto: 1094.20; Class3 -> Label: 1234.58, Auto: 1283.73; Class4 -> Label: 1624.99, Auto: 1656.19;
# Processed 00108.png: Class1 -> Label: 821.48, Auto: 779.88; Class2 -> Label: 1378.74, Auto: 1264.36; Class3 -> Label: 1247.81, Auto: 1229.85; Class4 -> Label: 1158.01, Auto: 1074.35;
# Processed 00040.png: Class1 -> Label: 1055.91, Auto: 981.71; Class2 -> Label: 634.78, Auto: 595.07; Class3 -> Label: 720.33, Auto: 592.24; Class4 -> Label: 1225.12, Auto: 956.66;
# Processed 00158.png: Class1 -> Label: 1451.05, Auto: 1510.61; Class2 -> Label: 1043.62, Auto: 1058.75; Class3 -> Label: 905.61, Auto: 905.14; Class4 -> Label: 1573.00, Auto: 1605.14;
# Processed 00161.png: Class1 -> Label: 1523.37, Auto: 1491.70; Class2 -> Label: 1042.68, Auto: 1147.61; Class3 -> Label: 984.07, Auto: 994.47; Class4 -> Label: 1608.45, Auto: 1695.42;
# Processed 00374.png: Class1 -> Label: 1355.58, Auto: 1304.06; Class2 -> Label: 1250.65, Auto: 1210.47; Class3 -> Label: 1267.19, Auto: 1294.13; Class4 -> Label: 1476.11, Auto: 1440.66;
# Processed 00096.png: Class1 -> Label: 1340.45, Auto: 1409.46; Class2 -> Label: 995.41, Auto: 967.05; Class3 -> Label: 898.99, Auto: 894.27; Class4 -> Label: 1451.53, Auto: 1446.33;
# Processed 00271.png: Class1 -> Label: 637.61, Auto: 1002.98; Class2 -> Label: 860.23, Auto: 877.72; Class3 -> Label: 842.75, Auto: 8.04; Class4 -> Label: 691.50, Auto: 619.18;
# Processed 00398.png: Class1 -> Label: 1365.50, Auto: 1015.27; Class2 -> Label: 823.37, Auto: 1089.47; Class3 -> Label: 739.71, Auto: 1274.75; Class4 -> Label: 1384.41, Auto: 847.00;
# Processed 00301.png: Class1 -> Label: 1270.97, Auto: 1245.92; Class2 -> Label: 796.43, Auto: 777.99; Class3 -> Label: 748.69, Auto: 747.27; Class4 -> Label: 1356.05, Auto: 1455.31;
# Processed 00009.png: Class1 -> Label: 1443.96, Auto: 1456.25; Class2 -> Label: 859.29, Auto: 27.41; Class3 -> Label: 869.69, Auto: 890.96; Class4 -> Label: 1388.19, Auto: 1535.66;
# Processed 00102.png: Class1 -> Label: 1282.79, Auto: 1276.64; Class2 -> Label: 1269.08, Auto: 1284.68; Class3 -> Label: 1169.82, Auto: 1241.20; Class4 -> Label: 1309.73, Auto: 1362.67;
# Processed 00329.png: Class1 -> Label: 958.07, Auto: 1434.04; Class2 -> Label: 1054.02, Auto: 504.80; Class3 -> Label: 910.34, Auto: 892.38; Class4 -> Label: 994.00, Auto: 975.56;
# Processed 00230.png: Class1 -> Label: 1656.19, Auto: 1111.69; Class2 -> Label: 976.04, Auto: 789.34; Class3 -> Label: 1012.43, Auto: 915.06; Class4 -> Label: 1524.79, Auto: 1567.80;
# Processed 00123.png: Class1 -> Label: 1332.89, Auto: 1284.68; Class2 -> Label: 838.02, Auto: 874.89; Class3 -> Label: 765.70, Auto: 820.53; Class4 -> Label: 1422.70, Auto: 1384.41;
# Processed 00364.png: Class1 -> Label: 1060.17, Auto: 959.49; Class2 -> Label: 1198.18, Auto: 1271.45; Class3 -> Label: 1191.57, Auto: 1155.17; Class4 -> Label: 1213.78, Auto: 1285.15;
# Processed 00180.png: Class1 -> Label: 1410.41, Auto: 1358.89; Class2 -> Label: 1169.82, Auto: 1104.12; Class3 -> Label: 1097.51, Auto: 1081.44; Class4 -> Label: 1331.95, Auto: 1336.20;
# Processed 00080.png: Class1 -> Label: 1165.10, Auto: 1082.38; Class2 -> Label: 628.16, Auto: 664.55; Class3 -> Label: 683.93, Auto: 700.95; Class4 -> Label: 1064.89, Auto: 1014.79;
# Processed 00380.png: Class1 -> Label: 555.84, Auto: 627.21; Class2 -> Label: 1149.50, Auto: 1192.04; Class3 -> Label: 1072.93, Auto: 1096.09; Class4 -> Label: 631.00, Auto: 723.16;
# Processed 00062.png: Class1 -> Label: 1149.97, Auto: 912.23; Class2 -> Label: 806.82, Auto: 750.58; Class3 -> Label: 830.93, Auto: 844.16; Class4 -> Label: 1390.08, Auto: 1421.28;
# Processed 00175.png: Class1 -> Label: 995.89, Auto: 589.40; Class2 -> Label: 1224.65, Auto: 1106.96; Class3 -> Label: 1205.75, Auto: 1025.19; Class4 -> Label: 1335.73, Auto: 614.45;
# Processed 00297.png: Class1 -> Label: 1460.98, Auto: 1273.81; Class2 -> Label: 973.67, Auto: 803.04; Class3 -> Label: 1024.72, Auto: 1080.02; Class4 -> Label: 1652.41, Auto: 1492.18;
# Processed 00083.png: Class1 -> Label: 1191.57, Auto: 1003.92; Class2 -> Label: 1099.40, Auto: 1065.84; Class3 -> Label: 1004.87, Auto: 867.80; Class4 -> Label: 1286.57, Auto: 1342.34;
# Processed 00120.png: Class1 -> Label: 1148.08, Auto: 1048.82; Class2 -> Label: 720.80, Auto: 756.72; Class3 -> Label: 803.99, Auto: 860.71; Class4 -> Label: 1315.40, Auto: 1173.61;
# Processed 00359.png: Class1 -> Label: 1457.67, Auto: 1324.86; Class2 -> Label: 739.71, Auto: 689.13; Class3 -> Label: 792.64, Auto: 779.88; Class4 -> Label: 1277.59, Auto: 1183.06;
# Processed 00200.png: Class1 -> Label: 1970.03, Auto: 1856.59; Class2 -> Label: 1208.58, Auto: 1242.61; Class3 -> Label: 1120.20, Auto: 1106.49; Class4 -> Label: 2247.95, Auto: 2241.34;
# Processed 00245.png: Class1 -> Label: 1012.43, Auto: 875.36; Class2 -> Label: 772.32, Auto: 810.13; Class3 -> Label: 673.06, Auto: 700.95; Class4 -> Label: 1148.55, Auto: 1144.30;
# Processed 00235.png: Class1 -> Label: 1348.49, Auto: 1119.72; Class2 -> Label: 1154.70, Auto: 1171.71; Class3 -> Label: 1072.46, Auto: 1041.73; Class4 -> Label: 1265.77, Auto: 1185.42;
# Processed 00340.png: Class1 -> Label: 1833.91, Auto: 1731.81; Class2 -> Label: 1237.89, Auto: 1325.33; Class3 -> Label: 1130.59, Auto: 1187.79; Class4 -> Label: 1920.40, Auto: 1886.37;
# Processed 00058.png: Class1 -> Label: 1516.75, Auto: 1385.36; Class2 -> Label: 700.95, Auto: 753.89; Class3 -> Label: 752.00, Auto: 826.68; Class4 -> Label: 1549.84, Auto: 1433.09;
# Processed 00221.png: Class1 -> Label: 770.43, Auto: 416.88; Class2 -> Label: 892.38, Auto: 857.40; Class3 -> Label: 830.93, Auto: 839.44; Class4 -> Label: 542.14, Auto: 582.79;
# Processed 00204.png: Class1 -> Label: 1210.95, Auto: 885.76; Class2 -> Label: 984.07, Auto: 827.15; Class3 -> Label: 884.81, Auto: 886.23; Class4 -> Label: 1421.75, Auto: 1386.77;
# Processed 00029.png: Class1 -> Label: 1789.48, Auto: 1407.57; Class2 -> Label: 812.50, Auto: 813.91; Class3 -> Label: 752.00, Auto: 704.73; Class4 -> Label: 1946.40, Auto: 1921.82;
# Processed 00290.png: Class1 -> Label: 949.09, Auto: 940.11; Class2 -> Label: 822.89, Auto: 745.85; Class3 -> Label: 847.00, Auto: 781.77; Class4 -> Label: 1089.95, Auto: 1130.12;
# Processed 00145.png: Class1 -> Label: 2040.93, Auto: 1286.57; Class2 -> Label: 1227.02, Auto: 1503.52; Class3 -> Label: 1271.45, Auto: 1369.76; Class4 -> Label: 2053.22, Auto: 1705.34;
# Processed 00024.png: Class1 -> Label: 1448.22, Auto: 1218.98; Class2 -> Label: 959.49, Auto: 1034.64; Class3 -> Label: 955.24, Auto: 1067.73; Class4 -> Label: 1539.91, Auto: 1254.90;
# Processed 00134.png: Class1 -> Label: 873.00, Auto: 793.12; Class2 -> Label: 1034.64, Auto: 1128.70; Class3 -> Label: 989.27, Auto: 1079.07; Class4 -> Label: 1003.45, Auto: 1220.87;
# Processed 00104.png: Class1 -> Label: 1389.14, Auto: 1382.52; Class2 -> Label: 921.21, Auto: 918.37; Class3 -> Label: 889.54, Auto: 901.36; Class4 -> Label: 1340.45, Auto: 1219.93;
# Processed 00331.png: Class1 -> Label: 1391.50, Auto: 1312.57; Class2 -> Label: 1078.60, Auto: 920.73; Class3 -> Label: 994.94, Auto: 919.79; Class4 -> Label: 1331.47, Auto: 1230.32;
# Processed 00215.png: Class1 -> Label: 1123.03, Auto: 1097.04; Class2 -> Label: 1377.32, Auto: 1346.60; Class3 -> Label: 1244.03, Auto: 1218.98; Class4 -> Label: 1499.27, Auto: 1368.34;
# Processed 00218.png: Class1 -> Label: 1039.37, Auto: 1003.45; Class2 -> Label: 836.60, Auto: 770.43; Class3 -> Label: 759.56, Auto: 747.27; Class4 -> Label: 1017.63, Auto: 1062.53;
# Processed 00313.png: Class1 -> Label: 1508.25, Auto: 1420.80; Class2 -> Label: 1098.45, Auto: 1078.60; Class3 -> Label: 1180.70, Auto: 1162.73; Class4 -> Label: 1523.37, Auto: 1555.04;
# Processed 00282.png: Class1 -> Label: 1237.41, Auto: 1119.72; Class2 -> Label: 771.38, Auto: 733.56; Class3 -> Label: 655.57, Auto: 572.86; Class4 -> Label: 1170.30, Auto: 1162.26;
# Processed 00287.png: Class1 -> Label: 1910.48, Auto: 1687.86; Class2 -> Label: 1197.71, Auto: 1294.61; Class3 -> Label: 1114.52, Auto: 1181.17; Class4 -> Label: 1945.45, Auto: 1779.55;
# Processed 00333.png: Class1 -> Label: 1933.64, Auto: 1710.54; Class2 -> Label: 778.46, Auto: 744.91; Class3 -> Label: 830.46, Auto: 835.18; Class4 -> Label: 1670.37, Auto: 1763.48;
# Processed 00034.png: Class1 -> Label: 1409.46, Auto: 1365.03; Class2 -> Label: 997.30, Auto: 940.11; Class3 -> Label: 834.71, Auto: 873.94; Class4 -> Label: 1530.93, Auto: 1381.57;
# Processed 00325.png: Class1 -> Label: 1813.11, Auto: 1726.61; Class2 -> Label: 1459.09, Auto: 1322.96; Class3 -> Label: 1549.37, Auto: 1634.45; Class4 -> Label: 1722.36, Auto: 1629.72;
# Processed 00304.png: Class1 -> Label: 1267.19, Auto: 997.78; Class2 -> Label: 887.65, Auto: 885.29; Class3 -> Label: 760.98, Auto: 773.27; Class4 -> Label: 1219.93, Auto: 1465.23;
# Processed 00273.png: Class1 -> Label: 801.15, Auto: 958.07; Class2 -> Label: 909.39, Auto: 851.25; Class3 -> Label: 864.96, Auto: 724.58; Class4 -> Label: 898.99, Auto: 1132.96;
# Processed 00125.png: Class1 -> Label: 1500.21, Auto: 1417.02; Class2 -> Label: 890.96, Auto: 821.48; Class3 -> Label: 822.89, Auto: 830.93; Class4 -> Label: 1589.07, Auto: 1614.12;
# Processed 00156.png: Class1 -> Label: 1556.93, Auto: 1526.68; Class2 -> Label: 1093.73, Auto: 1121.14; Class3 -> Label: 1060.17, Auto: 1146.19; Class4 -> Label: 1541.33, Auto: 1308.79;
# Processed 00288.png: Class1 -> Label: 1352.27, Auto: 903.25; Class2 -> Label: 1237.41, Auto: 1221.82; Class3 -> Label: 1126.81, Auto: 1098.45; Class4 -> Label: 1383.94, Auto: 1523.84;
# Processed 00323.png: Class1 -> Label: 1901.50, Auto: 1740.79; Class2 -> Label: 1115.00, Auto: 1152.81; Class3 -> Label: 1079.07, Auto: 918.37; Class4 -> Label: 1880.23, Auto: 1891.57;
# Processed 00069.png: Class1 -> Label: 912.70, Auto: 827.15; Class2 -> Label: 584.68, Auto: 577.11; Class3 -> Label: 649.90, Auto: 668.34; Class4 -> Label: 925.46, Auto: 921.68;
# Processed 00013.png: Class1 -> Label: 1139.10, Auto: 933.50; Class2 -> Label: 926.88, Auto: 927.35; Class3 -> Label: 928.77, Auto: 17.02; Class4 -> Label: 1230.80, Auto: 1256.32;
# Processed 00358.png: Class1 -> Label: 1066.79, Auto: 980.76; Class2 -> Label: 881.03, Auto: 799.73; Class3 -> Label: 989.74, Auto: 942.95; Class4 -> Label: 1195.82, Auto: 1073.40;
# Processed 00042.png: Class1 -> Label: 1165.57, Auto: 1066.79; Class2 -> Label: 604.05, Auto: 635.25; Class3 -> Label: 647.54, Auto: 701.42; Class4 -> Label: 1404.73, Auto: 1222.76;
# Processed 00255.png: Class1 -> Label: 1417.50, Auto: 1179.75; Class2 -> Label: 915.06, Auto: 1074.82; Class3 -> Label: 902.30, Auto: 1000.14; Class4 -> Label: 1187.79, Auto: 1193.93;
# Processed 00246.png: Class1 -> Label: 1089.95, Auto: 1006.29; Class2 -> Label: 823.37, Auto: 870.63; Class3 -> Label: 775.16, Auto: 805.41; Class4 -> Label: 1045.52, Auto: 1097.98;
# Processed 00030.png: Class1 -> Label: 699.53, Auto: 467.46; Class2 -> Label: 1085.69, Auto: 1115.00; Class3 -> Label: 1097.04, Auto: 1048.82; Class4 -> Label: 873.00, Auto: 895.21;
# Processed 00008.png: Class1 -> Label: 1452.95, Auto: 1357.94; Class2 -> Label: 1165.10, Auto: 1051.66; Class3 -> Label: 919.32, Auto: 1104.60; Class4 -> Label: 1796.57, Auto: 1610.81;
# Processed 00178.png: Class1 -> Label: 1270.97, Auto: 1216.14; Class2 -> Label: 726.95, Auto: 717.02; Class3 -> Label: 648.01, Auto: 611.14; Class4 -> Label: 1126.81, Auto: 1239.30;
# Processed 00196.png: Class1 -> Label: 1114.52, Auto: 761.45; Class2 -> Label: 817.70, Auto: 673.06; Class3 -> Label: 809.66, Auto: 776.10; Class4 -> Label: 1265.30, Auto: 1255.85;
# Processed 00157.png: Class1 -> Label: 1815.00, Auto: 1692.58; Class2 -> Label: 947.20, Auto: 916.48; Class3 -> Label: 969.42, Auto: 987.85; Class4 -> Label: 1936.95, Auto: 1939.78;
# Processed 00384.png: Class1 -> Label: 1516.28, Auto: 961.86; Class2 -> Label: 1033.23, Auto: 1002.98; Class3 -> Label: 960.91, Auto: 845.58; Class4 -> Label: 1482.25, Auto: 1325.33;
# Processed 00020.png: Class1 -> Label: 1292.71, Auto: 1192.04; Class2 -> Label: 740.18, Auto: 727.42; Class3 -> Label: 721.75, Auto: 673.06; Class4 -> Label: 1547.48, Auto: 1545.59;
# Processed 00317.png: Class1 -> Label: 925.93, Auto: 781.77; Class2 -> Label: 671.17, Auto: 669.75; Class3 -> Label: 827.15, Auto: 886.70; Class4 -> Label: 858.82, Auto: 643.76;
# Processed 00130.png: Class1 -> Label: 1488.87, Auto: 1403.79; Class2 -> Label: 1099.87, Auto: 1194.88; Class3 -> Label: 1045.52, Auto: 1091.84; Class4 -> Label: 1669.89, Auto: 1861.79;
# Processed 00115.png: Class1 -> Label: 1703.93, Auto: 1555.51; Class2 -> Label: 971.31, Auto: 1130.59; Class3 -> Label: 832.35, Auto: 786.50; Class4 -> Label: 1639.64, Auto: 1670.37;
# Processed 00394.png: Class1 -> Label: 1604.67, Auto: 2041.40; Class2 -> Label: 879.14, Auto: 1006.29; Class3 -> Label: 922.62, Auto: 982.18; Class4 -> Label: 1999.34, Auto: 1999.81;
# Processed 00149.png: Class1 -> Label: 1340.93, Auto: 1160.37; Class2 -> Label: 905.61, Auto: 898.99; Class3 -> Label: 850.31, Auto: 786.03; Class4 -> Label: 1387.72, Auto: 1349.43;
# Processed 00236.png: Class1 -> Label: 1201.49, Auto: 1048.82; Class2 -> Label: 1375.90, Auto: 1339.98; Class3 -> Label: 1242.61, Auto: 1216.14; Class4 -> Label: 1362.20, Auto: 1442.55;
# Processed 00268.png: Class1 -> Label: 1438.29, Auto: 1474.21; Class2 -> Label: 1103.65, Auto: 777.99; Class3 -> Label: 999.67, Auto: 890.01; Class4 -> Label: 1701.09, Auto: 2147.75;
# Processed 00117.png: Class1 -> Label: 1664.70, Auto: 1691.64; Class2 -> Label: 777.05, Auto: 859.76; Class3 -> Label: 756.25, Auto: 794.06; Class4 -> Label: 1799.88, Auto: 1803.18;
# Processed 00232.png: Class1 -> Label: 1131.07, Auto: 601.22; Class2 -> Label: 865.43, Auto: 608.31; Class3 -> Label: 753.89, Auto: 908.92; Class4 -> Label: 998.25, Auto: 803.04;
# Processed 00113.png: Class1 -> Label: 994.00, Auto: 734.98; Class2 -> Label: 1158.48, Auto: 1227.02; Class3 -> Label: 1160.84, Auto: 1223.23; Class4 -> Label: 1071.98, Auto: 1350.85;
# Processed 00339.png: Class1 -> Label: 1307.84, Auto: 968.00; Class2 -> Label: 901.36, Auto: 795.95; Class3 -> Label: 923.57, Auto: 854.56; Class4 -> Label: 1554.57, Auto: 1632.55;
# Processed 00350.png: Class1 -> Label: 2392.59, Auto: 1194.88; Class2 -> Label: 1419.39, Auto: 1348.96; Class3 -> Label: 1119.72, Auto: 1084.75; Class4 -> Label: 2234.25, Auto: 2166.18;
# Processed 00294.png: Class1 -> Label: 1158.95, Auto: 1053.08; Class2 -> Label: 908.45, Auto: 845.11; Class3 -> Label: 820.06, Auto: 803.04; Class4 -> Label: 1289.88, Auto: 1308.31;
# Processed 00383.png: Class1 -> Label: 1124.92, Auto: 1077.66; Class2 -> Label: 833.77, Auto: 849.36; Class3 -> Label: 790.28, Auto: 797.37; Class4 -> Label: 1233.16, Auto: 1284.68;
# Processed 00228.png: Class1 -> Label: 1477.05, Auto: 376.71; Class2 -> Label: 753.41, Auto: 1514.86; Class3 -> Label: 803.04, Auto: 825.73; Class4 -> Label: 1631.61, Auto: 1589.07;
# Processed 00033.png: Class1 -> Label: 1206.69, Auto: 1247.81; Class2 -> Label: 779.41, Auto: 757.67; Class3 -> Label: 799.26, Auto: 737.82; Class4 -> Label: 1175.97, Auto: 1158.48;
# Processed 00262.png: Class1 -> Label: 1672.26, Auto: 1679.82; Class2 -> Label: 1129.18, Auto: 1234.58; Class3 -> Label: 1132.96, Auto: 1350.85; Class4 -> Label: 1977.59, Auto: 1680.77;
# Processed 00292.png: Class1 -> Label: 857.40, Auto: 794.54; Class2 -> Label: 848.42, Auto: 850.78; Class3 -> Label: 798.79, Auto: 742.54; Class4 -> Label: 900.41, Auto: 997.78;
# Processed 00243.png: Class1 -> Label: 907.50, Auto: 883.87; Class2 -> Label: 776.10, Auto: 761.45; Class3 -> Label: 758.14, Auto: 734.04; Class4 -> Label: 871.58, Auto: 887.18;
# Processed 00127.png: Class1 -> Label: 1264.36, Auto: 1215.20; Class2 -> Label: 930.19, Auto: 984.07; Class3 -> Label: 930.19, Auto: 1025.66; Class4 -> Label: 1331.95, Auto: 1281.37;
# Processed 00150.png: Class1 -> Label: 846.53, Auto: 762.87; Class2 -> Label: 722.69, Auto: 739.23; Class3 -> Label: 701.42, Auto: 670.70; Class4 -> Label: 1026.14, Auto: 827.15;
# Processed 00101.png: Class1 -> Label: 1497.85, Auto: 1409.93; Class2 -> Label: 1071.04, Auto: 1053.55; Class3 -> Label: 1201.02, Auto: 1473.27; Class4 -> Label: 1509.66, Auto: 968.47;
# Processed 00194.png: Class1 -> Label: 1490.76, Auto: 1235.05; Class2 -> Label: 1185.89, Auto: 1245.45; Class3 -> Label: 1315.88, Auto: 1178.33; Class4 -> Label: 1722.36, Auto: 1675.09;
# Processed 00354.png: Class1 -> Label: 1522.43, Auto: 1345.65; Class2 -> Label: 821.00, Auto: 836.13; Class3 -> Label: 822.42, Auto: 849.84; Class4 -> Label: 1715.74, Auto: 1539.44;
# Processed 00351.png: Class1 -> Label: 1259.63, Auto: 1076.24; Class2 -> Label: 851.73, Auto: 674.01; Class3 -> Label: 773.74, Auto: 813.91; Class4 -> Label: 1390.55, Auto: 1369.29;
# Processed 00072.png: Class1 -> Label: 1002.50, Auto: 898.99; Class2 -> Label: 704.73, Auto: 659.83; Class3 -> Label: 735.45, Auto: 729.31; Class4 -> Label: 1031.81, Auto: 983.12;
# Processed 00147.png: Class1 -> Label: 1250.18, Auto: 1132.48; Class2 -> Label: 820.53, Auto: 714.66; Class3 -> Label: 832.35, Auto: 736.40; Class4 -> Label: 1183.53, Auto: 1268.14;
# Processed 00337.png: Class1 -> Label: 1714.80, Auto: 1345.65; Class2 -> Label: 1111.69, Auto: 1053.08; Class3 -> Label: 958.07, Auto: 938.70; Class4 -> Label: 1618.85, Auto: 1612.70;
# Processed 00059.png: Class1 -> Label: 1348.49, Auto: 1227.49; Class2 -> Label: 917.43, Auto: 864.49; Class3 -> Label: 865.91, Auto: 886.23; Class4 -> Label: 1508.25, Auto: 1352.27;
# Processed 00052.png: Class1 -> Label: 1324.38, Auto: 1228.91; Class2 -> Label: 1133.43, Auto: 1126.81; Class3 -> Label: 1026.14, Auto: 1017.63; Class4 -> Label: 1508.72, Auto: 1447.27;
# Processed 00279.png: Class1 -> Label: 1125.39, Auto: 875.83; Class2 -> Label: 760.03, Auto: 896.16; Class3 -> Label: 651.32, Auto: 656.05; Class4 -> Label: 1204.80, Auto: 1120.67;
# Processed 00265.png: Class1 -> Label: 856.45, Auto: 839.44; Class2 -> Label: 986.43, Auto: 970.36; Class3 -> Label: 994.94, Auto: 993.52; Class4 -> Label: 930.19, Auto: 934.44;
# Processed 00225.png: Class1 -> Label: 1268.61, Auto: 1180.22; Class2 -> Label: 939.17, Auto: 938.22; Class3 -> Label: 852.67, Auto: 862.12; Class4 -> Label: 1434.04, Auto: 1503.99;
# Processed 00274.png: Class1 -> Label: 1415.13, Auto: 1361.25; Class2 -> Label: 1017.63, Auto: 1020.46; Class3 -> Label: 999.67, Auto: 1031.34; Class4 -> Label: 1329.58, Auto: 1329.11;
# Processed 00081.png: Class1 -> Label: 1344.71, Auto: 1298.86; Class2 -> Label: 891.90, Auto: 870.16; Class3 -> Label: 910.81, Auto: 895.21; Class4 -> Label: 1331.95, Auto: 1368.34;
# Processed 00103.png: Class1 -> Label: 1190.62, Auto: 989.74; Class2 -> Label: 937.75, Auto: 667.86; Class3 -> Label: 953.82, Auto: 874.41; Class4 -> Label: 1159.90, Auto: 1094.20;
# Processed 00088.png: Class1 -> Label: 1612.23, Auto: 1513.92; Class2 -> Label: 1030.86, Auto: 1062.53; Class3 -> Label: 1058.75, Auto: 1072.93; Class4 -> Label: 1504.94, Auto: 1490.76;
# Processed 00090.png: Class1 -> Label: 1676.51, Auto: 1577.73; Class2 -> Label: 937.75, Auto: 936.33; Class3 -> Label: 1032.28, Auto: 1039.84; Class4 -> Label: 1677.46, Auto: 1528.57;
# Processed 00352.png: Class1 -> Label: 1656.19, Auto: 1726.61; Class2 -> Label: 921.21, Auto: 902.30; Class3 -> Label: 884.81, Auto: 898.05; Class4 -> Label: 1611.76, Auto: 1616.01;
# Processed 00356.png: Class1 -> Label: 1531.41, Auto: 1497.38; Class2 -> Label: 970.36, Auto: 924.99; Class3 -> Label: 890.48, Auto: 921.68; Class4 -> Label: 1529.52, Auto: 1615.07;
# Processed 00079.png: Class1 -> Label: 1404.73, Auto: 1301.70; Class2 -> Label: 778.46, Auto: 817.70; Class3 -> Label: 729.31, Auto: 779.41; Class4 -> Label: 1404.26, Auto: 1422.22;
# Processed 00406.png: Class1 -> Label: 1227.49, Auto: 1063.95; Class2 -> Label: 824.31, Auto: 866.38; Class3 -> Label: 760.03, Auto: 656.99; Class4 -> Label: 1279.48, Auto: 1389.14;
# Processed 00197.png: Class1 -> Label: 1398.59, Auto: 1313.98; Class2 -> Label: 1044.10, Auto: 926.41; Class3 -> Label: 977.93, Auto: 889.07; Class4 -> Label: 1424.59, Auto: 1484.61;
# Processed 00306.png: Class1 -> Label: 1875.03, Auto: 1596.16; Class2 -> Label: 1092.31, Auto: 1085.69; Class3 -> Label: 1009.12, Auto: 800.21; Class4 -> Label: 2102.38, Auto: 2069.29;
# Processed 00128.png: Class1 -> Label: 1511.08, Auto: 1278.06; Class2 -> Label: 1202.91, Auto: 968.47; Class3 -> Label: 1144.77, Auto: 1202.44; Class4 -> Label: 1358.41, Auto: 1283.73;
# Processed 00095.png: Class1 -> Label: 1427.89, Auto: 1313.51; Class2 -> Label: 737.34, Auto: 762.39; Class3 -> Label: 833.29, Auto: 884.34; Class4 -> Label: 1539.91, Auto: 1628.77;
# Processed 00343.png: Class1 -> Label: 1327.22, Auto: 1212.84; Class2 -> Label: 823.37, Auto: 750.11; Class3 -> Label: 914.12, Auto: 882.92; Class4 -> Label: 1368.34, Auto: 1428.37;
# Processed 00368.png: Class1 -> Label: 1144.77, Auto: 1018.10; Class2 -> Label: 1017.63, Auto: 1112.63; Class3 -> Label: 1044.57, Auto: 1119.72; Class4 -> Label: 1143.83, Auto: 1063.95;
# Processed 00362.png: Class1 -> Label: 1635.86, Auto: 1503.52; Class2 -> Label: 1071.98, Auto: 1090.89; Class3 -> Label: 1239.78, Auto: 1215.20; Class4 -> Label: 1269.55, Auto: 1352.74;
# Processed 00303.png: Class1 -> Label: 821.00, Auto: 482.11; Class2 -> Label: 1117.83, Auto: 1110.74; Class3 -> Label: 932.08, Auto: 1056.39; Class4 -> Label: 979.82, Auto: 1046.93;
# Processed 00214.png: Class1 -> Label: 1159.90, Auto: 1051.19; Class2 -> Label: 810.61, Auto: 842.75; Class3 -> Label: 798.79, Auto: 762.87; Class4 -> Label: 1304.06, Auto: 1313.98;
# Processed 00277.png: Class1 -> Label: 1132.96, Auto: 853.62; Class2 -> Label: 759.56, Auto: 890.48; Class3 -> Label: 783.19, Auto: 724.11; Class4 -> Label: 1017.63, Auto: 950.98;
# Processed 00357.png: Class1 -> Label: 1278.06, Auto: 1242.14; Class2 -> Label: 866.38, Auto: 723.64; Class3 -> Label: 847.47, Auto: 834.24; Class4 -> Label: 1379.21, Auto: 1374.96;
# Processed 00278.png: Class1 -> Label: 656.52, Auto: 622.49; Class2 -> Label: 959.49, Auto: 1012.90; Class3 -> Label: 940.11, Auto: 929.24; Class4 -> Label: 924.04, Auto: 985.96;
# Processed 00242.png: Class1 -> Label: 1001.56, Auto: 921.21; Class2 -> Label: 1084.75, Auto: 1104.12; Class3 -> Label: 1150.92, Auto: 1177.39; Class4 -> Label: 1057.80, Auto: 1030.86;
# Processed 00082.png: Class1 -> Label: 996.83, Auto: 995.41; Class2 -> Label: 739.23, Auto: 702.84; Class3 -> Label: 741.60, Auto: 772.79; Class4 -> Label: 1099.87, Auto: 1086.16;
# Processed 00247.png: Class1 -> Label: 1539.91, Auto: 1525.73; Class2 -> Label: 603.58, Auto: 635.72; Class3 -> Label: 608.31, Auto: 452.80; Class4 -> Label: 1466.65, Auto: 1538.02;
# Processed 00208.png: Class1 -> Label: 1207.64, Auto: 1191.09; Class2 -> Label: 980.76, Auto: 916.01; Class3 -> Label: 933.97, Auto: 894.27; Class4 -> Label: 1258.21, Auto: 1328.64;
# Processed 00111.png: Class1 -> Label: 1332.42, Auto: 1330.05; Class2 -> Label: 1038.90, Auto: 1027.55; Class3 -> Label: 949.09, Auto: 962.33; Class4 -> Label: 1375.90, Auto: 1410.88;
# Processed 00003.png: Class1 -> Label: 1678.88, Auto: 1622.16; Class2 -> Label: 1033.23, Auto: 958.07; Class3 -> Label: 964.69, Auto: 935.39; Class4 -> Label: 1655.71, Auto: 1671.31;
# Processed 00043.png: Class1 -> Label: 1434.98, Auto: 1371.18; Class2 -> Label: 900.88, Auto: 898.52; Class3 -> Label: 685.82, Auto: 774.68; Class4 -> Label: 1702.04, Auto: 1579.62;
# Processed 00376.png: Class1 -> Label: 1517.70, Auto: 1397.64; Class2 -> Label: 982.65, Auto: 990.69; Class3 -> Label: 876.78, Auto: 1186.37; Class4 -> Label: 1437.82, Auto: 1192.98;
# Processed 00386.png: Class1 -> Label: 1237.41, Auto: 760.98; Class2 -> Label: 841.80, Auto: 765.70; Class3 -> Label: 713.71, Auto: 556.32; Class4 -> Label: 1263.88, Auto: 1201.49;
# Processed 00139.png: Class1 -> Label: 1190.62, Auto: 1160.37; Class2 -> Label: 1232.69, Auto: 1099.40; Class3 -> Label: 1254.43, Auto: 1215.20; Class4 -> Label: 1218.51, Auto: 1270.03;
# Processed 00063.png: Class1 -> Label: 1605.14, Auto: 1511.08; Class2 -> Label: 898.05, Auto: 936.33; Class3 -> Label: 846.53, Auto: 888.59; Class4 -> Label: 1529.04, Auto: 1431.20;
# Processed 00234.png: Class1 -> Label: 1992.25, Auto: 1887.79; Class2 -> Label: 924.52, Auto: 892.85; Class3 -> Label: 847.47, Auto: 845.58; Class4 -> Label: 1566.86, Auto: 1535.19;
# Processed 00176.png: Class1 -> Label: 1322.96, Auto: 2133.57; Class2 -> Label: 1412.77, Auto: 1190.15; Class3 -> Label: 1283.73, Auto: 1313.98; Class4 -> Label: 1837.21, Auto: 1870.30;
# Processed 00189.png: Class1 -> Label: 1561.66, Auto: 1508.25; Class2 -> Label: 1159.43, Auto: 981.71; Class3 -> Label: 1208.58, Auto: 1100.34; Class4 -> Label: 1608.45, Auto: 1539.91;
# Processed 00211.png: Class1 -> Label: 1690.22, Auto: 1589.54; Class2 -> Label: 824.31, Auto: 851.73; Class3 -> Label: 778.46, Auto: 763.81; Class4 -> Label: 1716.21, Auto: 1826.34;
# Processed 00346.png: Class1 -> Label: 1213.78, Auto: 761.45; Class2 -> Label: 1316.35, Auto: 1192.98; Class3 -> Label: 1359.36, Auto: 1381.10; Class4 -> Label: 1206.22, Auto: 838.49;
# Processed 00021.png: Class1 -> Label: 1263.41, Auto: 847.95; Class2 -> Label: 901.36, Auto: 1131.54; Class3 -> Label: 863.54, Auto: 788.39; Class4 -> Label: 1449.16, Auto: 1406.62;
# Processed 00001.png: Class1 -> Label: 1252.54, Auto: 1230.32; Class2 -> Label: 943.42, Auto: 903.25; Class3 -> Label: 919.79, Auto: 886.70; Class4 -> Label: 1358.89, Auto: 1376.38;
# Processed 00144.png: Class1 -> Label: 1216.62, Auto: 1046.46; Class2 -> Label: 1073.88, Auto: 1068.68; Class3 -> Label: 1037.01, Auto: 984.54; Class4 -> Label: 1261.05, Auto: 1132.96;
# Processed 00166.png: Class1 -> Label: 1200.07, Auto: 963.27; Class2 -> Label: 722.22, Auto: 829.98; Class3 -> Label: 713.24, Auto: 697.17; Class4 -> Label: 1430.26, Auto: 1419.39;
# Processed 00395.png: Class1 -> Label: 1365.98, Auto: 1292.24; Class2 -> Label: 1048.82, Auto: 1006.29; Class3 -> Label: 962.80, Auto: 1065.37; Class4 -> Label: 1443.02, Auto: 1370.70;
# Processed 00067.png: Class1 -> Label: 1646.73, Auto: 1662.80; Class2 -> Label: 1318.71, Auto: 1413.71; Class3 -> Label: 1167.46, Auto: 1150.92; Class4 -> Label: 1554.09, Auto: 1593.80;
# Processed 00061.png: Class1 -> Label: 838.49, Auto: 726.47; Class2 -> Label: 1047.88, Auto: 969.42; Class3 -> Label: 940.59, Auto: 755.30; Class4 -> Label: 1226.07, Auto: 989.27;
# Processed 00226.png: Class1 -> Label: 1065.37, Auto: 969.42; Class2 -> Label: 690.08, Auto: 684.41; Class3 -> Label: 741.12, Auto: 631.00; Class4 -> Label: 1241.67, Auto: 1289.88;
# Processed 00298.png: Class1 -> Label: 1259.16, Auto: 907.97; Class2 -> Label: 1118.78, Auto: 1127.76; Class3 -> Label: 1008.18, Auto: 925.93; Class4 -> Label: 1175.02, Auto: 1138.63;
# Processed 00192.png: Class1 -> Label: 1332.89, Auto: 1210.00; Class2 -> Label: 1186.37, Auto: 891.90; Class3 -> Label: 1091.36, Auto: 1105.07; Class4 -> Label: 1447.27, Auto: 1442.55;
# Processed 00314.png: Class1 -> Label: 1049.30, Auto: 1132.01; Class2 -> Label: 870.16, Auto: 886.23; Class3 -> Label: 907.97, Auto: 891.90; Class4 -> Label: 1206.69, Auto: 1254.90;
# Processed 00177.png: Class1 -> Label: 1127.76, Auto: 1364.56; Class2 -> Label: 1074.35, Auto: 1017.63; Class3 -> Label: 972.73, Auto: 995.41; Class4 -> Label: 1317.29, Auto: 1395.28;
# Processed 00122.png: Class1 -> Label: 1602.30, Auto: 1550.31; Class2 -> Label: 858.34, Auto: 807.77; Class3 -> Label: 844.64, Auto: 829.04; Class4 -> Label: 1677.46, Auto: 1650.52;
# Processed 00164.png: Class1 -> Label: 881.98, Auto: 897.10; Class2 -> Label: 854.09, Auto: 834.24; Class3 -> Label: 723.64, Auto: 709.93; Class4 -> Label: 1030.86, Auto: 1063.00;
# Processed 00093.png: Class1 -> Label: 1565.91, Auto: 1328.64; Class2 -> Label: 1025.19, Auto: 1030.39; Class3 -> Label: 956.66, Auto: 944.37; Class4 -> Label: 1679.82, Auto: 1711.96;
# Processed 00318.png: Class1 -> Label: 1006.76, Auto: 964.22; Class2 -> Label: 1080.49, Auto: 1004.87; Class3 -> Label: 1203.86, Auto: 1247.34; Class4 -> Label: 1092.78, Auto: 1130.59;
# Processed 00085.png: Class1 -> Label: 1663.75, Auto: 1625.94; Class2 -> Label: 874.89, Auto: 892.85; Class3 -> Label: 1012.90, Auto: 990.21; Class4 -> Label: 1880.70, Auto: 1983.74;
# Processed 00073.png: Class1 -> Label: 1132.48, Auto: 950.51; Class2 -> Label: 1139.57, Auto: 1255.85; Class3 -> Label: 1063.95, Auto: 1012.90; Class4 -> Label: 1066.79, Auto: 1113.11;
# Processed 00266.png: Class1 -> Label: 1452.95, Auto: 1346.60; Class2 -> Label: 784.14, Auto: 797.37; Class3 -> Label: 798.79, Auto: 793.12; Class4 -> Label: 1553.62, Auto: 1523.84;
# Processed 00256.png: Class1 -> Label: 1166.99, Auto: 1074.35; Class2 -> Label: 1067.73, Auto: 1226.07; Class3 -> Label: 1133.90, Auto: 1062.53; Class4 -> Label: 1068.20, Auto: 664.55;
# Processed 00076.png: Class1 -> Label: 1272.39, Auto: 1189.68; Class2 -> Label: 1117.36, Auto: 1091.36; Class3 -> Label: 1105.07, Auto: 1089.47; Class4 -> Label: 1260.57, Auto: 1267.19;
# Processed 00039.png: Class1 -> Label: 966.58, Auto: 922.62; Class2 -> Label: 914.12, Auto: 817.22; Class3 -> Label: 909.86, Auto: 831.40; Class4 -> Label: 1034.64, Auto: 904.19;
# Processed 00283.png: Class1 -> Label: 1278.06, Auto: 1152.34; Class2 -> Label: 838.96, Auto: 752.00; Class3 -> Label: 832.82, Auto: 797.84; Class4 -> Label: 1409.93, Auto: 1402.84;
# Processed 00054.png: Class1 -> Label: 1407.57, Auto: 1283.26; Class2 -> Label: 993.52, Auto: 954.29; Class3 -> Label: 964.22, Auto: 1012.90; Class4 -> Label: 1553.62, Auto: 1535.19;
# Processed 00307.png: Class1 -> Label: 1443.02, Auto: 1347.07; Class2 -> Label: 1123.98, Auto: 1145.72; Class3 -> Label: 1132.96, Auto: 835.18; Class4 -> Label: 1236.47, Auto: 1252.07;
# Processed 00159.png: Class1 -> Label: 1060.17, Auto: 1080.02; Class2 -> Label: 876.30, Auto: 857.40; Class3 -> Label: 821.48, Auto: 850.31; Class4 -> Label: 1061.59, Auto: 1106.96;
# Processed 00057.png: Class1 -> Label: 1220.40, Auto: 1195.35; Class2 -> Label: 859.29, Auto: 847.47; Class3 -> Label: 937.75, Auto: 950.51; Class4 -> Label: 1353.69, Auto: 1274.75;
# Processed 00305.png: Class1 -> Label: 1663.75, Auto: 1491.70; Class2 -> Label: 1005.34, Auto: 1023.30; Class3 -> Label: 1044.57, Auto: 1050.24; Class4 -> Label: 1880.23, Auto: 1747.88;
# Processed 00397.png: Class1 -> Label: 1347.07, Auto: 1074.35; Class2 -> Label: 904.19, Auto: 893.79; Class3 -> Label: 835.66, Auto: 914.12; Class4 -> Label: 1325.33, Auto: 1495.96;
# Processed 00112.png: Class1 -> Label: 1102.23, Auto: 1000.14; Class2 -> Label: 1149.97, Auto: 1060.17; Class3 -> Label: 1121.61, Auto: 1063.95; Class4 -> Label: 1154.23, Auto: 1204.33;
# Processed 00186.png: Class1 -> Label: 1931.27, Auto: 1868.88; Class2 -> Label: 1183.53, Auto: 1174.55; Class3 -> Label: 1300.28, Auto: 1368.81; Class4 -> Label: 1669.42, Auto: 1611.29;
# Processed 00160.png: Class1 -> Label: 1077.66, Auto: 865.43; Class2 -> Label: 1239.30, Auto: 1270.50; Class3 -> Label: 1166.52, Auto: 1125.87; Class4 -> Label: 1251.59, Auto: 1155.64;
# Processed 00360.png: Class1 -> Label: 1668.95, Auto: 1352.74; Class2 -> Label: 1191.09, Auto: 1207.64; Class3 -> Label: 1018.10, Auto: 1005.81; Class4 -> Label: 1506.83, Auto: 1513.45;
# Processed 00347.png: Class1 -> Label: 2128.84, Auto: 1348.96; Class2 -> Label: 1051.66, Auto: 1229.38; Class3 -> Label: 964.22, Auto: 963.75; Class4 -> Label: 2048.49, Auto: 2284.82;
# Processed 00409.png: Class1 -> Label: 1379.68, Auto: 1314.46; Class2 -> Label: 899.46, Auto: 639.50; Class3 -> Label: 925.46, Auto: 947.68; Class4 -> Label: 1220.40, Auto: 1218.04;
# Processed 00185.png: Class1 -> Label: 1620.74, Auto: 1373.07; Class2 -> Label: 1291.30, Auto: 1300.75; Class3 -> Label: 1248.76, Auto: 1187.31; Class4 -> Label: 1492.18, Auto: 1447.75;
# Processed 00223.png: Class1 -> Label: 1808.38, Auto: 1050.24; Class2 -> Label: 933.50, Auto: 1380.16; Class3 -> Label: 1066.31, Auto: 1133.90; Class4 -> Label: 1767.26, Auto: 1578.67;
# Processed 00086.png: Class1 -> Label: 1605.61, Auto: 1472.80; Class2 -> Label: 969.89, Auto: 1014.32; Class3 -> Label: 941.06, Auto: 974.14; Class4 -> Label: 1729.92, Auto: 1760.17;
# Processed 00201.png: Class1 -> Label: 1693.53, Auto: 1525.73; Class2 -> Label: 941.06, Auto: 933.97; Class3 -> Label: 782.25, Auto: 785.08; Class4 -> Label: 1638.70, Auto: 1672.73;
# Processed 00344.png: Class1 -> Label: 1687.38, Auto: 1509.19; Class2 -> Label: 1066.79, Auto: 969.89; Class3 -> Label: 1097.98, Auto: 1072.93; Class4 -> Label: 1623.57, Auto: 1612.23;
# Processed 00293.png: Class1 -> Label: 1279.48, Auto: 1103.65; Class2 -> Label: 867.32, Auto: 722.22; Class3 -> Label: 822.42, Auto: 699.06; Class4 -> Label: 1466.18, Auto: 1388.66;
# Processed 00181.png: Class1 -> Label: 1159.43, Auto: 1748.83; Class2 -> Label: 973.20, Auto: 965.64; Class3 -> Label: 936.80, Auto: 938.70; Class4 -> Label: 1313.04, Auto: 1286.57;
# Processed 00137.png: Class1 -> Label: 1556.46, Auto: 1554.57; Class2 -> Label: 1283.26, Auto: 1062.53; Class3 -> Label: 1345.65, Auto: 1268.14; Class4 -> Label: 1446.80, Auto: 1615.54;
# Processed 00251.png: Class1 -> Label: 1607.03, Auto: 1564.02; Class2 -> Label: 1118.78, Auto: 1096.56; Class3 -> Label: 965.16, Auto: 907.03; Class4 -> Label: 1875.03, Auto: 1608.92;
# Processed 00322.png: Class1 -> Label: 1636.81, Auto: 1538.50; Class2 -> Label: 963.27, Auto: 1008.65; Class3 -> Label: 1013.85, Auto: 1000.14; Class4 -> Label: 1745.52, Auto: 1744.57;
# Processed 00361.png: Class1 -> Label: 1436.40, Auto: 1499.74; Class2 -> Label: 967.05, Auto: 929.71; Class3 -> Label: 941.06, Auto: 910.81; Class4 -> Label: 1198.66, Auto: 1336.67;
# Processed 00289.png: Class1 -> Label: 1685.96, Auto: 1467.12; Class2 -> Label: 723.64, Auto: 835.66; Class3 -> Label: 937.75, Auto: 924.99; Class4 -> Label: 1925.60, Auto: 1830.60;
# Processed 00316.png: Class1 -> Label: 1666.11, Auto: 1575.84; Class2 -> Label: 1091.84, Auto: 1120.67; Class3 -> Label: 1129.65, Auto: 1140.05; Class4 -> Label: 1858.01, Auto: 1823.04;
# Processed 00295.png: Class1 -> Label: 1207.16, Auto: 1224.65; Class2 -> Label: 933.50, Auto: 855.98; Class3 -> Label: 1061.59, Auto: 1052.61; Class4 -> Label: 1060.64, Auto: 1177.39;
# Processed 00132.png: Class1 -> Label: 1257.74, Auto: 1174.08; Class2 -> Label: 917.90, Auto: 890.01; Class3 -> Label: 954.29, Auto: 945.31; Class4 -> Label: 1342.34, Auto: 1424.59;
# Processed 00390.png: Class1 -> Label: 1651.93, Auto: 1455.31; Class2 -> Label: 1132.01, Auto: 1011.96; Class3 -> Label: 1099.40, Auto: 865.43; Class4 -> Label: 1768.21, Auto: 1801.77;
# Processed 00272.png: Class1 -> Label: 729.78, Auto: 870.16; Class2 -> Label: 981.71, Auto: 1016.21; Class3 -> Label: 854.56, Auto: 804.93; Class4 -> Label: 754.83, Auto: 1025.66;
# Processed 00190.png: Class1 -> Label: 1082.38, Auto: 1039.84; Class2 -> Label: 974.14, Auto: 906.08; Class3 -> Label: 926.41, Auto: 900.41; Class4 -> Label: 1198.66, Auto: 1169.82;
# Processed 00202.png: Class1 -> Label: 1147.14, Auto: 1055.44; Class2 -> Label: 1038.43, Auto: 1009.12; Class3 -> Label: 976.04, Auto: 1115.47; Class4 -> Label: 1317.29, Auto: 1190.15;
# Processed 00056.png: Class1 -> Label: 1519.59, Auto: 1426.00; Class2 -> Label: 940.59, Auto: 1040.79; Class3 -> Label: 984.07, Auto: 1085.69; Class4 -> Label: 1499.27, Auto: 1471.85;
# Processed 00269.png: Class1 -> Label: 1297.91, Auto: 1287.99; Class2 -> Label: 1002.03, Auto: 19.38; Class3 -> Label: 1171.71, Auto: 944.37; Class4 -> Label: 1417.02, Auto: 1324.38;
# ...
# Processed 00118.png: Class1 -> Label: 1159.43, Auto: 1024.25; Class2 -> Label: 1192.51, Auto: 1173.61; Class3 -> Label: 1093.73, Auto: 1145.25; Class4 -> Label: 1276.64, Auto: 1329.58;
# Processed 00336.png: Class1 -> Label: 1169.82, Auto: 917.90; Class2 -> Label: 1089.95, Auto: 1174.55; Class3 -> Label: 1079.07, Auto: 1065.84; Class4 -> Label: 1473.74, Auto: 1424.11;
# Processed 00051.png: Class1 -> Label: 1628.30, Auto: 1376.85; Class2 -> Label: 987.85, Auto: 1047.88; Class3 -> Label: 932.08, Auto: 985.49; Class4 -> Label: 1545.59, Auto: 1587.65;
# Processed 00275.png: Class1 -> Label: 1058.75, Auto: 807.77; Class2 -> Label: 896.16, Auto: 857.40; Class3 -> Label: 869.21, Auto: 405.07; Class4 -> Label: 1107.43, Auto: 1125.39;
# Processed 00335.png: Class1 -> Label: 1367.39, Auto: 1064.42; Class2 -> Label: 1012.90, Auto: 1030.86; Class3 -> Label: 996.83, Auto: 1075.77; Class4 -> Label: 1601.83, Auto: 1624.99;
# Processed 00151.png: Class1 -> Label: 1022.83, Auto: 916.48; Class2 -> Label: 855.04, Auto: 861.65; Class3 -> Label: 862.60, Auto: 869.69; Class4 -> Label: 990.69, Auto: 924.99;
# Processed 00227.png: Class1 -> Label: 1109.80, Auto: 1026.61; Class2 -> Label: 879.61, Auto: 734.98; Class3 -> Label: 911.75, Auto: 688.66; Class4 -> Label: 1477.05, Auto: 1361.72;
# Processed 00153.png: Class1 -> Label: 1688.33, Auto: 1461.45; Class2 -> Label: 984.07, Auto: 1064.42; Class3 -> Label: 796.43, Auto: 819.11; Class4 -> Label: 1830.60, Auto: 1768.68;
# Processed 00254.png: Class1 -> Label: 1322.02, Auto: 1257.74; Class2 -> Label: 1109.32, Auto: 1095.62; Class3 -> Label: 1115.00, Auto: 1083.80; Class4 -> Label: 1392.92, Auto: 1483.20;
# Processed 00259.png: Class1 -> Label: 899.94, Auto: 887.18; Class2 -> Label: 1233.63, Auto: 1291.30; Class3 -> Label: 1124.92, Auto: 1098.93; Class4 -> Label: 1137.68, Auto: 1226.07;
# Processed 00114.png: Class1 -> Label: 986.91, Auto: 932.55; Class2 -> Label: 959.02, Auto: 942.48; Class3 -> Label: 994.00, Auto: 1025.66; Class4 -> Label: 1218.98, Auto: 1235.52;
# Processed 00296.png: Class1 -> Label: 1462.87, Auto: 1459.56; Class2 -> Label: 980.29, Auto: 968.95; Class3 -> Label: 938.70, Auto: 936.80; Class4 -> Label: 1466.65, Auto: 1554.57;
# Processed 00205.png: Class1 -> Label: 1437.35, Auto: 1396.23; Class2 -> Label: 924.52, Auto: 927.82; Class3 -> Label: 942.48, Auto: 922.62; Class4 -> Label: 1370.23, Auto: 1331.00;
# Processed 00025.png: Class1 -> Label: 1196.29, Auto: 1110.74; Class2 -> Label: 1170.77, Auto: 1204.80; Class3 -> Label: 1121.14, Auto: 1063.48; Class4 -> Label: 1277.59, Auto: 1175.97;
# Processed 00216.png: Class1 -> Label: 1316.35, Auto: 1174.55; Class2 -> Label: 1169.82, Auto: 1127.29; Class3 -> Label: 1159.90, Auto: 1086.16; Class4 -> Label: 1619.32, Auto: 1524.79;
# Processed 00252.png: Class1 -> Label: 1242.14, Auto: 1188.26; Class2 -> Label: 1045.99, Auto: 1078.13; Class3 -> Label: 1031.34, Auto: 1013.85; Class4 -> Label: 1475.63, Auto: 1514.39;
# Processed 00055.png: Class1 -> Label: 1227.96, Auto: 1158.01; Class2 -> Label: 909.86, Auto: 907.97; Class3 -> Label: 958.55, Auto: 1030.86; Class4 -> Label: 1530.46, Auto: 1445.86;
# Processed 00410.png: Class1 -> Label: 1925.60, Auto: 1622.16; Class2 -> Label: 1193.93, Auto: 1125.39; Class3 -> Label: 1069.62, Auto: 1024.25; Class4 -> Label: 1936.95, Auto: 1492.18;
# Processed 00005.png: Class1 -> Label: 1495.48, Auto: 1208.11; Class2 -> Label: 969.89, Auto: 976.98; Class3 -> Label: 951.46, Auto: 954.77; Class4 -> Label: 1615.54, Auto: 1827.76;
# Processed 00203.png: Class1 -> Label: 990.21, Auto: 883.87; Class2 -> Label: 908.45, Auto: 838.96; Class3 -> Label: 925.93, Auto: 929.71; Class4 -> Label: 1031.81, Auto: 1138.63;
# Processed 00179.png: Class1 -> Label: 1529.04, Auto: 1857.54; Class2 -> Label: 1036.06, Auto: 1045.04; Class3 -> Label: 1016.68, Auto: 1005.34; Class4 -> Label: 1745.99, Auto: 1720.00;
# Processed 00375.png: Class1 -> Label: 1188.73, Auto: 1185.42; Class2 -> Label: 860.23, Auto: 889.07; Class3 -> Label: 789.81, Auto: 924.04; Class4 -> Label: 947.20, Auto: 897.10;
# Processed 00312.png: Class1 -> Label: 1926.07, Auto: 2118.92; Class2 -> Label: 1193.46, Auto: 1053.55; Class3 -> Label: 1042.68, Auto: 1011.48; Class4 -> Label: 1851.87, Auto: 1772.93;
# Processed 00310.png: Class1 -> Label: 1115.47, Auto: 910.34; Class2 -> Label: 819.11, Auto: 735.93; Class3 -> Label: 916.48, Auto: 906.08; Class4 -> Label: 1303.59, Auto: 1202.44;
# Processed 00385.png: Class1 -> Label: 2055.58, Auto: 1014.79; Class2 -> Label: 662.19, Auto: 799.73; Class3 -> Label: 914.12, Auto: 356.86; Class4 -> Label: 1807.91, Auto: 709.93;
# Processed 00391.png: Class1 -> Label: 1521.01, Auto: 1643.43; Class2 -> Label: 925.93, Auto: 881.03; Class3 -> Label: 872.05, Auto: 636.20; Class4 -> Label: 1461.93, Auto: 1482.72;
# Processed 00035.png: Class1 -> Label: 1064.89, Auto: 1000.14; Class2 -> Label: 783.19, Auto: 774.21; Class3 -> Label: 889.54, Auto: 848.89; Class4 -> Label: 980.29, Auto: 944.84;
# Processed 00036.png: Class1 -> Label: 911.28, Auto: 612.56; Class2 -> Label: 1046.93, Auto: 968.95; Class3 -> Label: 958.07, Auto: 931.61; Class4 -> Label: 1253.48, Auto: 1053.55;
# Processed 00133.png: Class1 -> Label: 829.04, Auto: 549.70; Class2 -> Label: 1085.22, Auto: 1088.53; Class3 -> Label: 943.89, Auto: 942.00; Class4 -> Label: 1389.61, Auto: 1479.41;
# Processed 00173.png: Class1 -> Label: 974.62, Auto: 494.87; Class2 -> Label: 1078.13, Auto: 1196.77; Class3 -> Label: 1080.02, Auto: 1064.89; Class4 -> Label: 1460.04, Auto: 1317.77;
# Processed 00404.png: Class1 -> Label: 1215.20, Auto: 1016.68; Class2 -> Label: 1433.09, Auto: 1282.79; Class3 -> Label: 1277.59, Auto: 1363.61; Class4 -> Label: 1123.50, Auto: 863.07;
# Processed 00032.png: Class1 -> Label: 1322.49, Auto: 1004.87; Class2 -> Label: 1005.34, Auto: 1087.58; Class3 -> Label: 918.84, Auto: 1063.95; Class4 -> Label: 1434.51, Auto: 1133.43;
# Processed 00015.png: Class1 -> Label: 1000.14, Auto: 867.32; Class2 -> Label: 1064.42, Auto: 1031.81; Class3 -> Label: 1086.16, Auto: 1020.94; Class4 -> Label: 1046.93, Auto: 1116.89;
# Processed 00330.png: Class1 -> Label: 1272.86, Auto: 1060.17; Class2 -> Label: 1046.46, Auto: 1056.39; Class3 -> Label: 1255.38, Auto: 1275.70; Class4 -> Label: 1507.77, Auto: 1591.91;
# Processed 00213.png: Class1 -> Label: 1287.99, Auto: 1230.32; Class2 -> Label: 772.32, Auto: 754.36; Class3 -> Label: 942.48, Auto: 874.89; Class4 -> Label: 1367.39, Auto: 1293.66;
# Processed 00399.png: Class1 -> Label: 1124.92, Auto: 1041.26; Class2 -> Label: 914.12, Auto: 811.08; Class3 -> Label: 926.88, Auto: 813.44; Class4 -> Label: 1082.38, Auto: 907.03;
# Processed 00400.png: Class1 -> Label: 1201.96, Auto: 940.11; Class2 -> Label: 892.38, Auto: 770.43; Class3 -> Label: 921.21, Auto: 908.45; Class4 -> Label: 1331.95, Auto: 1396.70;
# Processed 00026.png: Class1 -> Label: 1094.67, Auto: 492.51; Class2 -> Label: 876.30, Auto: 1382.99; Class3 -> Label: 862.60, Auto: 824.79; Class4 -> Label: 1218.04, Auto: 1236.00;
# Processed 00075.png: Class1 -> Label: 1763.01, Auto: 1688.80; Class2 -> Label: 656.99, Auto: 663.14; Class3 -> Label: 609.73, Auto: 617.29; Class4 -> Label: 1530.93, Auto: 1542.28;
# Processed 00006.png: Class1 -> Label: 1446.80, Auto: 1072.93; Class2 -> Label: 805.41, Auto: 722.22; Class3 -> Label: 753.89, Auto: 697.17; Class4 -> Label: 1450.58, Auto: 1146.19;
# Processed 00280.png: Class1 -> Label: 1281.84, Auto: 1081.44; Class2 -> Label: 923.57, Auto: 935.39; Class3 -> Label: 811.55, Auto: 833.29; Class4 -> Label: 1352.27, Auto: 1229.38;
# Processed 00046.png: Class1 -> Label: 1451.53, Auto: 1287.04; Class2 -> Label: 858.34, Auto: 805.88; Class3 -> Label: 777.05, Auto: 734.51; Class4 -> Label: 1793.26, Auto: 1719.52;
# Processed 00092.png: Class1 -> Label: 1083.80, Auto: 949.57; Class2 -> Label: 1215.20, Auto: 1200.07; Class3 -> Label: 1043.15, Auto: 1026.61; Class4 -> Label: 1341.40, Auto: 1353.21;
# Processed 00342.png: Class1 -> Label: 1032.28, Auto: 976.98; Class2 -> Label: 903.72, Auto: 933.97; Class3 -> Label: 929.71, Auto: 777.52; Class4 -> Label: 1158.95, Auto: 1359.36;
# Processed 00182.png: Class1 -> Label: 1069.15, Auto: 1135.32; Class2 -> Label: 977.93, Auto: 865.43; Class3 -> Label: 940.59, Auto: 939.17; Class4 -> Label: 1070.57, Auto: 1327.22;
# Processed 00162.png: Class1 -> Label: 1521.48, Auto: 1374.96; Class2 -> Label: 1003.45, Auto: 1040.79; Class3 -> Label: 997.78, Auto: 1046.46; Class4 -> Label: 1517.23, Auto: 1511.55;
# Processed 00379.png: Class1 -> Label: 1288.93, Auto: 1166.52; Class2 -> Label: 1119.25, Auto: 1061.11; Class3 -> Label: 1028.97, Auto: 1072.93; Class4 -> Label: 1410.88, Auto: 1454.36;
# Processed 00089.png: Class1 -> Label: 1538.97, Auto: 1484.61; Class2 -> Label: 990.21, Auto: 1004.87; Class3 -> Label: 949.57, Auto: 901.83; Class4 -> Label: 1611.76, Auto: 1549.37;
# Processed 00148.png: Class1 -> Label: 1331.00, Auto: 1042.68; Class2 -> Label: 812.97, Auto: 1022.36; Class3 -> Label: 767.12, Auto: 790.75; Class4 -> Label: 1477.05, Auto: 1511.55;
# Processed 00167.png: Class1 -> Label: 1415.61, Auto: 1116.89; Class2 -> Label: 733.09, Auto: 786.03; Class3 -> Label: 709.93, Auto: 635.25; Class4 -> Label: 1656.66, Auto: 1578.67;
# Processed 00007.png: Class1 -> Label: 1166.99, Auto: 955.24; Class2 -> Label: 759.56, Auto: 893.79; Class3 -> Label: 693.86, Auto: 652.27; Class4 -> Label: 1168.88, Auto: 1216.14;
# Processed 00168.png: Class1 -> Label: 1085.69, Auto: 1010.07; Class2 -> Label: 1095.62, Auto: 1069.15; Class3 -> Label: 1168.41, Auto: 1171.24; Class4 -> Label: 1209.05, Auto: 1126.34;
# Processed 00138.png: Class1 -> Label: 1153.28, Auto: 1167.93; Class2 -> Label: 912.23, Auto: 943.42; Class3 -> Label: 932.08, Auto: 967.53; Class4 -> Label: 1298.86, Auto: 1332.42;
# Processed 00170.png: Class1 -> Label: 1166.99, Auto: 957.60; Class2 -> Label: 792.64, Auto: 791.70; Class3 -> Label: 825.26, Auto: 769.48; Class4 -> Label: 1157.54, Auto: 1030.39;
# Processed 00031.png: Class1 -> Label: 1478.47, Auto: 1317.77; Class2 -> Label: 1287.52, Auto: 1249.70; Class3 -> Label: 1305.00, Auto: 1350.85; Class4 -> Label: 1495.96, Auto: 1479.89;
# Processed 00142.png: Class1 -> Label: 1263.41, Auto: 1042.21; Class2 -> Label: 850.31, Auto: 855.04; Class3 -> Label: 877.25, Auto: 863.07; Class4 -> Label: 1489.34, Auto: 1395.75;
# Processed 00140.png: Class1 -> Label: 1074.82, Auto: 927.35; Class2 -> Label: 1090.89, Auto: 812.50; Class3 -> Label: 959.49, Auto: 897.10; Class4 -> Label: 1171.71, Auto: 1287.52;
# Processed 00155.png: Class1 -> Label: 1291.30, Auto: 1119.25; Class2 -> Label: 849.36, Auto: 879.61; Class3 -> Label: 955.71, Auto: 972.73; Class4 -> Label: 1288.46, Auto: 1268.61;
# Processed 00105.png: Class1 -> Label: 1017.63, Auto: 994.00; Class2 -> Label: 1114.05, Auto: 1151.39; Class3 -> Label: 1021.41, Auto: 1019.52; Class4 -> Label: 1163.68, Auto: 1290.35;
# Processed 00321.png: Class1 -> Label: 975.09, Auto: 800.21; Class2 -> Label: 524.18, Auto: 561.52; Class3 -> Label: 548.28, Auto: 549.70; Class4 -> Label: 1005.81, Auto: 1111.21;
# Processed 00300.png: Class1 -> Label: 1244.03, Auto: 1279.01; Class2 -> Label: 893.32, Auto: 877.25; Class3 -> Label: 841.33, Auto: 830.93; Class4 -> Label: 1400.01, Auto: 1494.54;
# Processed 00320.png: Class1 -> Label: 1272.86, Auto: 1216.14; Class2 -> Label: 894.74, Auto: 980.29; Class3 -> Label: 918.37, Auto: 971.31; Class4 -> Label: 1276.64, Auto: 1214.25;
# Processed 00327.png: Class1 -> Label: 1345.18, Auto: 908.45; Class2 -> Label: 610.20, Auto: 1010.54; Class3 -> Label: 666.45, Auto: 601.22; Class4 -> Label: 1529.52, Auto: 1293.19;
# Processed 00206.png: Class1 -> Label: 1528.10, Auto: 1160.84; Class2 -> Label: 785.55, Auto: 776.57; Class3 -> Label: 810.61, Auto: 758.14; Class4 -> Label: 1384.41, Auto: 1259.63;
# Processed 00163.png: Class1 -> Label: 1043.62, Auto: 1018.10; Class2 -> Label: 702.84, Auto: 674.01; Class3 -> Label: 745.85, Auto: 799.26; Class4 -> Label: 1095.14, Auto: 1098.93;
# Processed 00371.png: Class1 -> Label: 1269.08, Auto: 1185.42; Class2 -> Label: 1050.24, Auto: 1066.79; Class3 -> Label: 927.35, Auto: 911.75; Class4 -> Label: 849.84, Auto: 896.16;
# Processed 00141.png: Class1 -> Label: 1379.21, Auto: 1294.13; Class2 -> Label: 928.30, Auto: 937.75; Class3 -> Label: 893.32, Auto: 825.73; Class4 -> Label: 1285.62, Auto: 1254.43;
# Processed 00229.png: Class1 -> Label: 1109.80, Auto: 1098.93; Class2 -> Label: 899.46, Auto: 844.64; Class3 -> Label: 880.09, Auto: 910.34; Class4 -> Label: 1139.10, Auto: 1162.73;
# Processed 00345.png: Class1 -> Label: 1620.74, Auto: 1564.02; Class2 -> Label: 818.17, Auto: 765.23; Class3 -> Label: 898.52, Auto: 1032.28; Class4 -> Label: 1424.59, Auto: 1257.27;
# Processed 00348.png: Class1 -> Label: 1500.21, Auto: 1428.84; Class2 -> Label: 1288.93, Auto: 1225.60; Class3 -> Label: 1313.51, Auto: 1273.34; Class4 -> Label: 1783.80, Auto: 1789.95;
# Processed 00338.png: Class1 -> Label: 943.42, Auto: 876.78; Class2 -> Label: 1249.23, Auto: 1236.00; Class3 -> Label: 1347.07, Auto: 1240.72; Class4 -> Label: 1174.55, Auto: 1406.62;
# Processed 00249.png: Class1 -> Label: 1551.73, Auto: 1558.82; Class2 -> Label: 883.39, Auto: 864.49; Class3 -> Label: 775.63, Auto: 772.32; Class4 -> Label: 1333.84, Auto: 1262.46;
# Processed 00016.png: Class1 -> Label: 1510.61, Auto: 1069.62; Class2 -> Label: 1017.63, Auto: 1354.63; Class3 -> Label: 1013.38, Auto: 1206.69; Class4 -> Label: 1396.70, Auto: 1113.58;
# Processed 00264.png: Class1 -> Label: 1171.24, Auto: 1225.60; Class2 -> Label: 1190.62, Auto: 1236.47; Class3 -> Label: 1228.43, Auto: 1250.18; Class4 -> Label: 1367.39, Auto: 1428.84;
# Processed 00248.png: Class1 -> Label: 1491.23, Auto: 1328.16; Class2 -> Label: 679.68, Auto: 721.75; Class3 -> Label: 637.14, Auto: 669.75; Class4 -> Label: 1444.44, Auto: 1397.17;
# Processed 00260.png: Class1 -> Label: 2097.65, Auto: 1612.70; Class2 -> Label: 1167.93, Auto: 1425.53; Class3 -> Label: 1254.43, Auto: 1260.10; Class4 -> Label: 2030.06, Auto: 1946.40;
# Processed 00237.png: Class1 -> Label: 1382.05, Auto: 1204.80; Class2 -> Label: 847.47, Auto: 914.12; Class3 -> Label: 910.81, Auto: 1369.76; Class4 -> Label: 1660.91, Auto: 1088.53;
# Processed 00341.png: Class1 -> Label: 1526.21, Auto: 1653.82; Class2 -> Label: 902.30, Auto: 900.88; Class3 -> Label: 904.66, Auto: 886.23; Class4 -> Label: 1602.78, Auto: 1627.83;
# Processed 00250.png: Class1 -> Label: 1184.95, Auto: 970.36; Class2 -> Label: 917.43, Auto: 931.61; Class3 -> Label: 1090.42, Auto: 1068.20; Class4 -> Label: 1219.93, Auto: 1275.23;
# Processed 00047.png: Class1 -> Label: 1009.59, Auto: 979.82; Class2 -> Label: 999.20, Auto: 953.82; Class3 -> Label: 1013.38, Auto: 1079.55; Class4 -> Label: 1190.62, Auto: 1204.33;
# Processed 00311.png: Class1 -> Label: 1688.33, Auto: 1639.64; Class2 -> Label: 1035.59, Auto: 1035.59; Class3 -> Label: 1012.90, Auto: 1010.07; Class4 -> Label: 1867.46, Auto: 1971.45;
# Processed 00308.png: Class1 -> Label: 1283.26, Auto: 1167.46; Class2 -> Label: 925.93, Auto: 933.97; Class3 -> Label: 945.79, Auto: 937.28; Class4 -> Label: 1295.55, Auto: 1382.05;
# Processed 00349.png: Class1 -> Label: 1308.79, Auto: 1380.63; Class2 -> Label: 1855.18, Auto: 1721.89; Class3 -> Label: 1636.81, Auto: 1667.53; Class4 -> Label: 2102.85, Auto: 2029.59;
# Processed 00091.png: Class1 -> Label: 1158.48, Auto: 1071.51; Class2 -> Label: 1048.35, Auto: 1087.11; Class3 -> Label: 1042.68, Auto: 1069.15; Class4 -> Label: 1546.06, Auto: 1533.30;
# Processed 00377.png: Class1 -> Label: 715.13, Auto: 661.72; Class2 -> Label: 795.48, Auto: 770.43; Class3 -> Label: 851.73, Auto: 805.41; Class4 -> Label: 736.40, Auto: 743.02;
# Results saved to ./videos/MRI515_T2/manual_prompt_frame0/manual_prompt_frame0_area_results_long.csv
#      PID  Class    Auto Area  Manual Area
# 0  00261      1  1153.281250  1229.851562
# 1  00261      2  1147.136719  1147.136719
# 2  00261      3  1198.656250  1229.378906
# 3  00261      4  1246.394531  1206.218750
# 4  00212      1  1433.566406  1400.953125

# %%
results_long_df
# Out:
#         PID  Class    Auto Area  Manual Area
# 0     00261      1  1153.281250  1229.851562
# 1     00261      2  1147.136719  1147.136719
# 2     00261      3  1198.656250  1229.378906
# 3     00261      4  1246.394531  1206.218750
# 4     00212      1  1433.566406  1400.953125
# ...     ...    ...          ...          ...
# 1639  00091      4  1533.296875  1546.058594
# 1640  00377      1   661.718750   715.128906
# 1641  00377      2   770.429688   795.480469
# 1642  00377      3   805.406250   851.726562
# 1643  00377      4   743.015625   736.398438
#
# [1644 rows x 4 columns]

# %%
manual_prompt_id = ['00000', '00001', '00002']
# 逻辑：根据 prompt_dir 中是否包含 "1" 或 "2" 来决定去除 manual_prompt_id 中的前几项
remove_prefixes = manual_prompt_id[: 1 + ("1" in prompt_dir) + ("2" in prompt_dir)]
print("Remove prefixes:", remove_prefixes)
filter_pid = lambda df: df[~df["PID"].astype(str).str.startswith(tuple(remove_prefixes))]
results_df = filter_pid(results_long_df)
results_df
# Out:
# Remove prefixes: ['00000']
#         PID  Class    Auto Area  Manual Area
# 0     00261      1  1153.281250  1229.851562
# 1     00261      2  1147.136719  1147.136719
# 2     00261      3  1198.656250  1229.378906
# 3     00261      4  1246.394531  1206.218750
# 4     00212      1  1433.566406  1400.953125
# ...     ...    ...          ...          ...
# 1639  00091      4  1533.296875  1546.058594
# 1640  00377      1   661.718750   715.128906
# 1641  00377      2   770.429688   795.480469
# 1642  00377      3   805.406250   851.726562
# 1643  00377      4   743.015625   736.398438
#
# [1640 rows x 4 columns]

# %%
import numpy as np
import pandas as pd
import pingouin as pg
from scipy.stats import ttest_ind, ks_2samp, shapiro

# 假设 df_results 已经包含了分割面积计算结果，
# 并且包含 "PID", "Class", "Manual Area", "Auto Area" 等列

# ----------------- 统计学检验、MAPE 和 ICC -----------------
# 用于存储各类别的 MAPE 和 ICC 结果
mape_results = []  # 每项格式：[Class, MAPE, MAPE_std]
icc_results = []   # 每项格式：[Class, ICC, ICC_95%_CI_Lower, ICC_95%_CI_Upper]
# 用于存储每个类别的 p-value
p_value_dict = {}
df_results = results_df
# 对每个类别进行统计检验及误差、ICC 分析
for class_value in [1, 2, 3, 4]:
    df_class = df_results[df_results["Class"] == class_value]
    if df_class.empty:
        continue

    # 提取手动分割（Label）与自动分割（Auto Area）数值
    label_values = df_class["Manual Area"].values *100
    auto_values = df_class["Auto Area"].values*100

    # -------------- 正态性检验 --------------
    shapiro_label = shapiro(label_values)
    shapiro_auto_seg = shapiro(auto_values)

    label_is_normal = shapiro_label.pvalue >= 0.05
    auto_seg_is_normal = shapiro_auto_seg.pvalue >= 0.05

    print(f"\nClass {class_value}:")
    print(f"  Shapiro-Wilk Normality Test (Label): p-value = {shapiro_label.pvalue:.3f} -> {'Normal' if label_is_normal else 'Non-Normal'}")
    print(f"  Shapiro-Wilk Normality Test (Auto-Seg): p-value = {shapiro_auto_seg.pvalue:.3f} -> {'Normal' if auto_seg_is_normal else 'Non-Normal'}")

    # -------------- 选择统计检验方法 --------------
    if label_is_normal and auto_seg_is_normal:
        t_stat, p_value = ttest_ind(label_values, auto_values, equal_var=False)
        print("  Method: Independent Two-Sample T-Test")
        print(f"  T-statistic: {t_stat:.4f}, P-value: {p_value:.3f}")
    else:
        ks_stat, p_value = ks_2samp(label_values, auto_values)
        print("  Method: Kolmogorov-Smirnov Test")
        print(f"  KS-statistic: {ks_stat:.4f}, P-value: {p_value:.3f}")

    # 存储 p-value，用于后续汇总打印
    p_value_dict[class_value] = p_value

    # -------------- 解释检验结果 --------------
    if p_value < 0.05:
        print("  - Significant difference detected (p < 0.05).")
    else:
        print("  - No significant difference detected (p >= 0.05).")

    # -------------- 计算 MAPE --------------
    # 防止除 0，使用一个很小的 epsilon
    epsilon = 1e-6
    ape = np.abs((auto_values - label_values) / (label_values + epsilon))
    mape = np.mean(ape)
    mape_std = np.std(ape)
    mape_results.append([class_value, mape, mape_std])

    # -------------- 计算 ICC --------------
    df_long = df_class.melt(id_vars=["PID"], value_vars=["Manual Area", "Auto Area"],
                            var_name="Method", value_name="Area")
    icc_df = pg.intraclass_corr(data=df_long, targets="PID", raters="Method", ratings="Area")
    # 提取 ICC2 相关行
    icc_row = icc_df[icc_df["Type"] == "ICC2"].iloc[0]
    icc_value = icc_row["ICC"]
    if "CI95%" in icc_row:
        ci_lower, ci_upper = icc_row["CI95%"]
    else:
        ci_lower, ci_upper = np.nan, np.nan
    icc_results.append([class_value, icc_value, ci_lower, ci_upper])

# ----------------- 显示 MAPE 和 ICC 结果 -----------------
mape_df = pd.DataFrame(mape_results, columns=['Class', 'MAPE', 'MAPE_std'])
icc_df = pd.DataFrame(icc_results, columns=['Class', 'ICC', 'ICC_95%_CI_Lower', 'ICC_95%_CI_Upper'])

# 将 MAPE 及其标准差转换为百分比格式，保留一位小数
mape_df['MAPE'] = (mape_df['MAPE'] * 100).round(1)
mape_df['MAPE_std'] = (mape_df['MAPE_std'] * 100).round(1)

mape_df = mape_df.sort_values(by="Class")
icc_df = icc_df.sort_values(by="Class")

# 打印 MAPE 结果，格式示例：14.9 ± 13.1%
print("\n### MAPE Results ###")
for _, row in mape_df.iterrows():
    print(f"Class {int(row['Class'])}: {row['MAPE']} ± {row['MAPE_std']}%")

# 打印 ICC 结果（包含 95% 置信区间）
print("\n### ICC Results ###")
for _, row in icc_df.iterrows():
    print(f"Class {int(row['Class'])}: {row['ICC']:.3f}, [{row['ICC_95%_CI_Lower']:.2f} - {row['ICC_95%_CI_Upper']:.2f}]")

# ----------------- 汇总打印 p-value -----------------
# 定义类别与对应的名称（根据需要调整）
class_label_mapping = {
    1: "Right LES",
    2: "Right MF",
    3: "Left MF",
    4: "Left LES"
}
print("\n### p-values Summary ###")
# 打印第一行：类别名称和对应的编号
header = " ".join([f"{class_label_mapping[cv]} {cv}" for cv in [1, 2, 3, 4]])
# 打印第二行：对应的 p-value，保留三位小数
p_values_line = " ".join([f"{p_value_dict.get(cv, np.nan):.3f}" for cv in [1, 2, 3, 4]])
print(header)
print(p_values_line)
# Out:
# Class 1:
#   Shapiro-Wilk Normality Test (Label): p-value = 0.002 -> Non-Normal
#   Shapiro-Wilk Normality Test (Auto-Seg): p-value = 0.058 -> Normal
#   Method: Kolmogorov-Smirnov Test
#   KS-statistic: 0.2098, P-value: 0.000
#   - Significant difference detected (p < 0.05).
#
# Class 2:
#   Shapiro-Wilk Normality Test (Label): p-value = 0.000 -> Non-Normal
#   Shapiro-Wilk Normality Test (Auto-Seg): p-value = 0.000 -> Non-Normal
#   Method: Kolmogorov-Smirnov Test
#   KS-statistic: 0.0585, P-value: 0.484
#   - No significant difference detected (p >= 0.05).
#
# Class 3:
#   Shapiro-Wilk Normality Test (Label): p-value = 0.001 -> Non-Normal
#   Shapiro-Wilk Normality Test (Auto-Seg): p-value = 0.000 -> Non-Normal
#   Method: Kolmogorov-Smirnov Test
#   KS-statistic: 0.0683, P-value: 0.295
#   - No significant difference detected (p >= 0.05).
#
# Class 4:
#   Shapiro-Wilk Normality Test (Label): p-value = 0.015 -> Non-Normal
#   Shapiro-Wilk Normality Test (Auto-Seg): p-value = 0.081 -> Normal
#   Method: Kolmogorov-Smirnov Test
#   KS-statistic: 0.0585, P-value: 0.484
#   - No significant difference detected (p >= 0.05).
#
# ### MAPE Results ###
# Class 1: 12.7 ± 12.2%
# Class 2: 8.3 ± 12.7%
# Class 3: 7.8 ± 12.2%
# Class 4: 7.5 ± 8.9%
#
# ### ICC Results ###
# Class 1: 0.718, [0.43 - 0.84]
# Class 2: 0.782, [0.74 - 0.82]
# Class 3: 0.793, [0.75 - 0.83]
# Class 4: 0.855, [0.82 - 0.88]
#
# ### p-values Summary ###
# Right LES 1 Right MF 2 Left MF 3 Left LES 4
# 0.000 0.484 0.295 0.484
